# %% [markdown]
# <a href="https://colab.research.google.com/github/YTW0415/Kaggle_Basketball/blob/main/Kaggle_basket_20230307.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Dataset 불러오기 - 태원's github 주소에서 불러오는거니 실제 수상 시 없애고 자기 깃허브 주소로 변경 바랍니다

# %%
# !git clone https://github.com/YTW0415/Kaggle_Basketball.git
# Out:
# fatal: destination path 'Kaggle_Basketball' already exists and is not an empty directory.

# %% [markdown]
# # Adapting the 2nd Place Solution of the 2021 NCAAW Competition
#
# - Solution write-up is available here : https://www.kaggle.com/c/ncaaw-march-mania-2021/discussion/230705
# - 2nd place code : https://www.kaggle.com/theoviel/2nd-place-ncaaw-2021?scriptVersionId=58780991
# - It was adapted from this notebook : https://www.kaggle.com/theoviel/ncaa-starter-the-simpler-the-better
#
# **Changes :**
# - Build one model for both Men and Women
# - Update metric to MSE

# %%
import os
import re
import sklearn
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from collections import Counter
from sklearn.metrics import *
from sklearn.linear_model import *
from sklearn.model_selection import *

pd.set_option('display.max_columns', None)

# %%
DATA_PATH = '/content/Kaggle_Basketball/march-machine-learning-mania-2023/'

for filename in sorted(os.listdir(DATA_PATH)):
    print(filename)
# Out:
# Cities.csv
# Conferences.csv
# MConferenceTourneyGames.csv
# MGameCities.csv
# MMasseyOrdinals.csv
# MNCAATourneyCompactResults.csv
# MNCAATourneyDetailedResults.csv
# MNCAATourneySeedRoundSlots.csv
# MNCAATourneySeeds.csv
# MNCAATourneySlots.csv
# MRegularSeasonCompactResults.csv
# MRegularSeasonDetailedResults.csv
# MSeasons.csv
# MSecondaryTourneyCompactResults.csv
# MSecondaryTourneyTeams.csv
# MTeamCoaches.csv
# MTeamConferences.csv
# MTeamSpellings.csv
# MTeams.csv
# SampleSubmission2023.csv
# WGameCities.csv
# WNCAATourneyCompactResults.csv
# WNCAATourneyDetailedResults.csv
# WNCAATourneySeeds.csv
# WNCAATourneySlots.csv
# WRegularSeasonCompactResults.csv
# WRegularSeasonDetailedResults.csv
# WSeasons.csv
# WTeamConferences.csv
# WTeamSpellings.csv
# WTeams.csv
# kenpom0823.csv

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Seeds
# > This file identifies the seeds for all teams in each NCAA® tournament, for all seasons of historical data. Thus, there are between 64-68 rows for each year, depending on whether there were any play-in games and how many there were. In recent years the structure has settled at 68 total teams, with four "play-in" games leading to the final field of 64 teams entering Round 1 on Thursday of the first week (by definition, that is DayNum=136 each season). We will not know the seeds of the respective tournament teams, or even exactly which 68 teams it will be, until Selection Sunday on March 15, 2020 (DayNum=132).
#
# > The seed is a 3/4-character :
# - First character : Region (W, X, Y, or Z)
# - Next two digits : Seed within the region (01 to 16)
# - Last character (optional): Distinguishes teams between play-ins ( a or b)

# %%
df_seeds = pd.concat([
    pd.read_csv(DATA_PATH + "MNCAATourneySeeds.csv"),
    pd.read_csv(DATA_PATH + "WNCAATourneySeeds.csv"),
], ignore_index=True)
    
df_seeds.head()
# Out:
#    Season Seed  TeamID
# 0    1985  W01    1207
# 1    1985  W02    1210
# 2    1985  W03    1228
# 3    1985  W04    1260
# 4    1985  W05    1374

# %%
df_seeds['Seed'].value_counts()
# Out:
# W01     61
# X14     61
# Y01     61
# Y02     61
# Y03     61
#         ..
# Z13a     1
# Z13b     1
# Y12a     1
# Y12b     1
# Z14b     1
# Name: Seed, Length: 90, dtype: int64

# %% [markdown]
# ## Conference

# %%
df_conference = pd.concat([
    pd.read_csv(DATA_PATH + "MTeamConferences.csv"),
    pd.read_csv(DATA_PATH + "WTeamConferences.csv"),
], ignore_index=True)
    
df_conference.head()
# Out:
#    Season  TeamID ConfAbbrev
# 0    1985    1102        wac
# 1    1985    1103        ovc
# 2    1985    1104        sec
# 3    1985    1106       swac
# 4    1985    1108       swac

# %% [markdown]
# ## Season results
# > This file identifies the game-by-game results for many seasons of historical data, starting with the 1985 season (the first year the NCAA® had a 64-team tournament). For each season, the file includes all games played from DayNum 0 through 132. It is important to realize that the "Regular Season" games are simply defined to be all games played on DayNum=132 or earlier (DayNum=132 is Selection Sunday, and there are always a few conference tournament finals actually played early in the day on Selection Sunday itself). Thus a game played on or before Selection Sunday will show up here whether it was a pre-season tournament, a non-conference game, a regular conference game, a conference tournament game, or whatever.

# %%
df_season_results = pd.concat([
    pd.read_csv(DATA_PATH + "MRegularSeasonCompactResults.csv"),
    pd.read_csv(DATA_PATH + "WRegularSeasonCompactResults.csv"),
], ignore_index=True)

df_season_results.drop(['NumOT', 'WLoc'], axis=1, inplace=True)

# %%
df_season_results['ScoreGap'] = df_season_results['WScore'] - df_season_results['LScore']

# %%
df_season_results.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore  ScoreGap
# 0    1985      20     1228      81     1328      64        17
# 1    1985      25     1106      77     1354      70         7
# 2    1985      25     1112      63     1223      56         7
# 3    1985      25     1165      70     1432      54        16
# 4    1985      25     1192      86     1447      74        12

# %% [markdown]
# ### Features
# For each team at each season, I compute :
# - Number of wins
# - Number of losses
# - Average score gap of wins
# - Average score gap of losses
#
# And use the following features :
# - Win Ratio
# - Average score gap

# %%
num_win = df_season_results.groupby(['Season', 'WTeamID']).count()
num_win = num_win.reset_index()[['Season', 'WTeamID', 'DayNum']].rename(columns={"DayNum": "NumWins", "WTeamID": "TeamID"})

# %%
num_loss = df_season_results.groupby(['Season', 'LTeamID']).count()
num_loss = num_loss.reset_index()[['Season', 'LTeamID', 'DayNum']].rename(columns={"DayNum": "NumLosses", "LTeamID": "TeamID"})

# %%
gap_win = df_season_results.groupby(['Season', 'WTeamID']).mean().reset_index()
gap_win = gap_win[['Season', 'WTeamID', 'ScoreGap']].rename(columns={"ScoreGap": "GapWins", "WTeamID": "TeamID"})

# %%
gap_loss = df_season_results.groupby(['Season', 'LTeamID']).mean().reset_index()
gap_loss = gap_loss[['Season', 'LTeamID', 'ScoreGap']].rename(columns={"ScoreGap": "GapLosses", "LTeamID": "TeamID"})

# %% [markdown]
# Merge

# %%
df_features_season_w = df_season_results.groupby(['Season', 'WTeamID']).count().reset_index()[['Season', 'WTeamID']].rename(columns={"WTeamID": "TeamID"})
df_features_season_l = df_season_results.groupby(['Season', 'LTeamID']).count().reset_index()[['Season', 'LTeamID']].rename(columns={"LTeamID": "TeamID"})

# %%
df_features_season = pd.concat([df_features_season_w, df_features_season_l], axis=0).drop_duplicates().sort_values(['Season', 'TeamID']).reset_index(drop=True)

# %%
df_features_season = df_features_season.merge(num_win, on=['Season', 'TeamID'], how='left')
df_features_season = df_features_season.merge(num_loss, on=['Season', 'TeamID'], how='left')
df_features_season = df_features_season.merge(gap_win, on=['Season', 'TeamID'], how='left')
df_features_season = df_features_season.merge(gap_loss, on=['Season', 'TeamID'], how='left')

# %%
df_features_season.fillna(0, inplace=True)

# %%
df_features_season = df_features_season.groupby(['TeamID','Season'])[df_features_season.columns[2:]].mean().reset_index()

# %%
df_features_season_3year = df_features_season.sort_values('Season').groupby(['TeamID'])[df_features_season.columns[2:]].rolling(3).mean().reset_index()

df_features_season_3year = df_features_season_3year[['NumWins','NumLosses','GapWins','GapLosses']]

df_features_season_3year.columns = df_features_season_3year.columns + '_3years'

df_features_season = pd.concat([df_features_season,df_features_season_3year],axis=1)

df_features_season.loc[df_features_season['NumWins_3years'].isnull(), df_features_season_3year.columns] = df_features_season.loc[df_features_season['NumWins_3years'].isnull(),df_features_season.iloc[:,2:6].columns].values

# %%
df_features_season
# Out:
#        TeamID  Season  NumWins  NumLosses    GapWins  GapLosses  \
# 0        1101    2014      2.0       19.0   3.500000  17.473684
# 1        1101    2015      7.0       21.0  12.142857  18.523810
# 2        1101    2016      9.0       18.0   7.555556  13.388889
# 3        1101    2017      9.0       16.0   4.666667  10.062500
# 4        1101    2018     12.0       15.0   7.333333   9.733333
# ...       ...     ...      ...        ...        ...        ...
# 21423    3473    2023      1.0       22.0   9.000000  19.318182
# 21424    3474    2023      5.0       18.0  10.200000  19.888889
# 21425    3475    2023      8.0       16.0  13.875000  11.625000
# 21426    3476    2023      7.0       19.0  10.571429  13.368421
# 21427    3477    2023     11.0       15.0  11.000000  16.733333
#
#        NumWins_3years  NumLosses_3years  GapWins_3years  GapLosses_3years
# 0            2.000000         19.000000        3.500000         17.473684
# 1            7.000000         21.000000       12.142857         18.523810
# 2            6.000000         19.333333        7.732804         16.462128
# 3            8.333333         18.333333        8.121693         13.991733
# 4           10.000000         16.333333        6.518519         11.061574
# ...               ...               ...             ...               ...
# 21423        1.000000         22.000000        9.000000         19.318182
# 21424        5.000000         18.000000       10.200000         19.888889
# 21425        8.000000         16.000000       13.875000         11.625000
# 21426        7.000000         19.000000       10.571429         13.368421
# 21427       11.000000         15.000000       11.000000         16.733333
#
# [21428 rows x 10 columns]

# %% [markdown]
# ### Seed count add (0307)

# %%
df_features_season = df_features_season.merge(df_seeds, on=['Season', 'TeamID'], how='left').fillna('X0')

# %%
def treat_seed(seed):
    return int(re.sub("[^0-9]", "", seed))

df_features_season['Seed'] = df_features_season['Seed'].apply(treat_seed)

# %%
# Adding 1 to each season and averaging can help you find the number of seeds and tournament appearances over 5 years as of last year

df_features_seed_3year = df_features_season.copy()

df_features_seed_3year.loc[df_features_seed_3year['Seed'] > 0,'TourneyY'] = 1

df_features_seed_3year.loc[df_features_seed_3year['Seed'] == 0,'TourneyY'] = 0

df_features_seed_3year['Season'] = df_features_seed_3year['Season'] + 1

df_features_seed_3year = df_features_seed_3year.sort_values('Season').groupby(['TeamID'])['TourneyY'].rolling(5).sum().fillna(method='bfill').reset_index()

df_features_seed_3year.columns = df_features_seed_3year.columns + '_3years'

df_features_seed_3year = df_features_seed_3year['TourneyY_3years']

df_features_season = pd.concat([df_features_season,df_features_seed_3year],axis=1)

#Three years of missing values based on the data start year, and new teams may also be missing. 
#The new team wants to fill the missing values with zero and set the learning period to start in 2001.

df_features_season.loc[df_features_season['TourneyY_3years'].isnull(), 'TourneyY_3years'] = 0

# %%
df_features_season['TourneyY_3years'].value_counts()
# Out:
# 0.0    13170
# 1.0     3660
# 2.0     1869
# 3.0     1171
# 4.0      856
# 5.0      702
# Name: TourneyY_3years, dtype: int64

# %% [markdown]
# Compute features

# %%
df_features_season['WinRatio'] = df_features_season['NumWins'] / (df_features_season['NumWins'] + df_features_season['NumLosses'])
df_features_season['GapAvg'] = (
    (df_features_season['NumWins'] * df_features_season['GapWins'] - 
    df_features_season['NumLosses'] * df_features_season['GapLosses'])
    / (df_features_season['NumWins'] + df_features_season['NumLosses'])
)

# %%
df_features_season['WinRatio_3years'] = df_features_season['NumWins_3years'] / (df_features_season['NumWins_3years'] + df_features_season['NumLosses_3years'])
df_features_season['GapAvg_3years'] = (
    (df_features_season['NumWins_3years'] * df_features_season['GapWins_3years'] - 
    df_features_season['NumLosses_3years'] * df_features_season['GapLosses_3years'])
    / (df_features_season['NumWins_3years'] + df_features_season['NumLosses_3years'])
)

# %%
# df_features_season.drop(['NumWins', 'NumLosses', 'GapWins', 'GapLosses'], axis=1, inplace=True)

df_features_season.drop(df_features_season_3year.columns, axis=1, inplace=True)

# %%
df_features_season[df_features_season['Season'] == 2023].sort_values(by='WinRatio')
# Out:
#        TeamID  Season  NumWins  NumLosses    GapWins  GapLosses  Seed  \
# 19573    3389    2023      0.0       26.0   0.000000  20.423077     0
# 15380    3216    2023      0.0       24.0   0.000000  28.291667     0
# 17383    3298    2023      1.0       25.0  20.000000  19.520000     0
# 5276     1254    2023      1.0       24.0   4.000000  18.750000     0
# 21423    3473    2023      1.0       22.0   9.000000  19.318182     0
# ...       ...     ...      ...        ...        ...        ...   ...
# 20468    3424    2023     24.0        2.0  16.666667  16.000000     0
# 4161     1222    2023     25.0        2.0  21.760000   3.500000     0
# 16493    3261    2023     25.0        1.0  30.640000  24.000000     0
# 15741    3231    2023     26.0        1.0  22.153846   5.000000     0
# 19248    3376    2023     27.0        0.0  32.444444   0.000000     0
#
#        TourneyY_3years  WinRatio     GapAvg  WinRatio_3years  GapAvg_3years
# 19573              0.0  0.000000 -20.423077         0.305882      -8.948389
# 15380              0.0  0.000000 -28.291667         0.106061     -19.665010
# 17383              0.0  0.038462 -18.000000         0.231884      -8.021983
# 5276               0.0  0.040000 -17.840000         0.347222      -6.017802
# 21423              0.0  0.043478 -18.086957         0.043478     -18.086957
# ...                ...       ...        ...              ...            ...
# 20468              1.0  0.923077  14.153846         0.792683       8.934282
# 4161               3.0  0.925926  19.888889         0.885057      18.221836
# 16493              1.0  0.961538  28.538462         0.756410      10.313114
# 15741              3.0  0.962963  21.148148         0.825000      15.293974
# 19248              3.0  1.000000  32.444444         0.928571      23.156748
#
# [724 rows x 12 columns]

# %% [markdown]
# ## Season Results - detail

# %% [markdown]
# - WFGM - field goals made (by the winning team)
# - WFGA - field goals attempted (by the winning team)
# - WFGM3 - three pointers made (by the winning team)
# - WFGA3 - three pointers attempted (by the winning team)
# - WTO - turnovers committed (by the winning team)
# - WFTM - free throws made (by the winning team)
# - WFTA - free throws attempted (by the winning team)
# - WOR - offensive rebounds (pulled by the winning team)
# - Possessions per game = Field goals attempted - offensive rebounds + turnovers + 0.475 x free throws attempted
# ---
#
# - WDR - defensive rebounds (pulled by the winning team)
# - WAst - assists (by the winning team)
# - WStl - steals (accomplished by the winning team)
# - WBlk - blocks (accomplished by the winning team)
# - WPF - personal fouls committed (by the winning team)

# %%
regseason_detail_df = pd.concat([
    pd.read_csv(DATA_PATH + "MRegularSeasonDetailedResults.csv"),
    pd.read_csv(DATA_PATH + "WRegularSeasonDetailedResults.csv"),
], ignore_index=True)

regseason_detail_df.drop(['NumOT', 'WLoc'], axis=1, inplace=True)

# %%
win_team_only = regseason_detail_df.drop(['WAst','LAst','LStl','WStl','LBlk','WBlk','LPF','WPF','DayNum'], axis=1)
win_team_only.rename(columns={'WTeamName': 'TeamName'}, inplace=True)
win_team_only.rename(columns={'WTeamID': 'TeamID'}, inplace=True)
win_team_only.rename(columns={'LTeamID': 'OpponentTeamID'}, inplace=True)

team_factors_list = ['Score','FGM','FGA','FGA3','FGM3','TO','FTM','FTA','RankPOM','OR']
for factor in team_factors_list:
    win_team_only.rename(columns={'W'+factor: factor}, inplace=True)
    win_team_only.rename(columns={'L'+factor: 'Opponent'+factor}, inplace=True)

win_team_only['wins'] = 1 

win_team_only = win_team_only[['Season','TeamID','wins','Score','OpponentScore',
                               'FGM','FGA','OpponentFGM','OpponentFGA','FGM3','FGA3',
                               'OpponentFGM3','OpponentFGA3','FTM','FTA','OpponentFTM',
                               'OpponentFTA','TO','OpponentTO',
                               'OR','OpponentOR','OpponentTeamID']]

# %%
loss_team_only = regseason_detail_df.drop(['WAst','LAst','LStl','WStl','LBlk','WBlk','LPF','WPF','DayNum'], axis=1)
loss_team_only.rename(columns={'LTeamName': 'TeamName'}, inplace=True)
loss_team_only.rename(columns={'LTeamID': 'TeamID'}, inplace=True)
loss_team_only.rename(columns={'WTeamID': 'OpponentTeamID'}, inplace=True)

for factor in team_factors_list:
    loss_team_only.rename(columns={'L'+factor: factor}, inplace=True)
    loss_team_only.rename(columns={'W'+factor: 'Opponent'+factor}, inplace=True)

loss_team_only['wins'] = 0

loss_team_only = loss_team_only[['Season','TeamID','wins','Score','OpponentScore',
                               'FGM','FGA','OpponentFGM','OpponentFGA','FGM3','FGA3',
                               'OpponentFGM3','OpponentFGA3','FTM','FTA','OpponentFTM',
                               'OpponentFTA','TO','OpponentTO',
                               'OR','OpponentOR','OpponentTeamID']]

# %%
reg_season_all = win_team_only.append(loss_team_only)

# %%
reg_season_all['TOmargin'] = reg_season_all['TO']-reg_season_all['OpponentTO']

reg_season_all['FG'] = reg_season_all['FGM']/reg_season_all['FGA']
reg_season_all['FGopponent'] = reg_season_all['OpponentFGM']/reg_season_all['OpponentFGA']

reg_season_all['FG3'] = reg_season_all['FGM3']/reg_season_all['FGA3']
reg_season_all['FG3opponent'] = reg_season_all['OpponentFGM3']/reg_season_all['OpponentFGA3']

reg_season_all['FT'] = reg_season_all['FTM']/reg_season_all['FTA']

reg_season_all['Possession'] = (reg_season_all['FGA'] -reg_season_all['OR'] +reg_season_all['TO'] + reg_season_all['FTA'] * 0.44) *0.96

reg_season_all['Possessionopponent'] = (reg_season_all['OpponentFGA'] -reg_season_all['OpponentOR'] +reg_season_all['OpponentTO'] + reg_season_all['OpponentFTA'] * 0.44)  *0.96

# %%
pd.options.display.float_format = '{:.2f}'.format

reg_season_all.corr()['wins'].sort_values()
# Out:
# OpponentScore        -0.49
# FGopponent           -0.48
# OpponentFGM          -0.40
# FG3opponent          -0.30
# OpponentFTM          -0.30
# TOmargin             -0.28
# OpponentFTA          -0.27
# OpponentFGM3         -0.19
# TO                   -0.17
# FGA3                 -0.04
# Possession           -0.02
# OpponentOR           -0.02
# FGA                  -0.02
# OpponentTeamID       -0.00
# Season                0.00
# TeamID                0.00
# OpponentFGA           0.02
# OR                    0.02
# Possessionopponent    0.02
# OpponentFGA3          0.04
# FT                    0.14
# OpponentTO            0.17
# FGM3                  0.19
# FTA                   0.27
# FTM                   0.30
# FG3                   0.30
# FGM                   0.40
# FG                    0.48
# Score                 0.49
# wins                  1.00
# Name: wins, dtype: float64

# %%
# 쓸모없는 것 드랍

reg_season_all = reg_season_all.drop(['TO','OpponentTO','FGM','FGA','OpponentFGA','OpponentFGM','FGM3','FGA3','OpponentFGM3','OpponentFGA3','FTM','FTA','OpponentFTM','OpponentFTA'], axis=1)

# %%
reg_season_all = reg_season_all.merge(reg_season_all.groupby(['TeamID','Season'])['Possession'].mean().reset_index(),
                                      on=['Season', 'TeamID'],
                                      suffixes=('', '_Average'))

reg_season_all = reg_season_all.merge(reg_season_all.groupby(['OpponentTeamID','Season'])['Possessionopponent'].mean().reset_index(),
                                                              on=['Season', 'OpponentTeamID'],
                                                              suffixes=('', '_Average'))

# %%
reg_season_all
# Out:
#         Season  TeamID  wins  Score  OpponentScore  OR  OpponentOR  \
# 0         2003    1104     1     68             62  14          10
# 1         2003    1400     1     67             61  18           9
# 2         2003    1400     1     76             71   9          15
# 3         2003    1242     0     70             77  16           8
# 4         2003    1304     0     51             76  10          12
# ...        ...     ...   ...    ...            ...  ..         ...
# 353677    2023    3226     0     47             48  13           5
# 353678    2023    3225     1     77             70   4           8
# 353679    2023    3225     0     43             53   7           9
# 353680    2023    3430     0     55             73   6           9
# 353681    2023    3370     0     73             80  18           7
#
#         OpponentTeamID  TOmargin   FG  FGopponent  FG3  FG3opponent   FT  \
# 0                 1328         5 0.47        0.42 0.21         0.20 0.61
# 1                 1328        -4 0.39        0.42 0.36         0.50 0.60
# 2                 1328         4 0.54        0.42 0.55         0.38 0.64
# 3                 1328        -1 0.34        0.48 0.36         0.56 0.70
# 4                 1328         8 0.40        0.44 0.08         0.42 0.50
# ...                ...       ...  ...         ...  ...          ...  ...
# 353677            3340         7 0.38        0.35 0.13         0.50 0.58
# 353678            3340        -1 0.53        0.39 0.35         0.48 0.93
# 353679            3340         0 0.29        0.37 0.12         0.13 0.67
# 353680            3340         2 0.43        0.45 0.45         0.47 0.57
# 353681            3340        -2 0.34        0.44 0.32         0.36 0.71
#
#         Possession  Possessionopponent  Possession_Average  \
# 0            71.92               67.85               63.46
# 1            62.21               61.06               67.34
# 2            62.40               61.56               67.34
# 3            68.66               67.81               70.58
# 4            67.24               66.70               65.76
# ...            ...                 ...                 ...
# 353677       56.91               58.60               64.60
# 353678       62.55               65.78               70.55
# 353679       63.63               64.70               70.55
# 353680       64.40               70.69               66.34
# 353681       79.83               77.61               70.39
#
#         Possessionopponent_Average
# 0                            61.81
# 1                            61.81
# 2                            61.81
# 3                            61.81
# 4                            61.81
# ...                            ...
# 353677                       63.91
# 353678                       63.91
# 353679                       63.91
# 353680                       63.91
# 353681                       63.91
#
# [353682 rows x 18 columns]

# %% [markdown]
# ### KenPom Score 추가
# - Adjusted Offensive Efficiency : (Points Scored / Possessions) * (Opponent Average Possessions / 100)
# - Adjusted Defensive Efficiency = (Points Allowed / Possessions) * (Opponent Average Possessions / 100)
# - Adjusted Efficiency Margin = Adjusted Offensive Efficiency - Adjusted Defensive Efficiency
# - Expected Winning Percentage = (Adjusted Offensive Efficiency ^ 11.5) / [(Adjusted Offensive Efficiency ^ 11.5) + (Adjusted Defensive Efficiency ^ 11.5)]

# %%
reg_season_all['AdjO'] = reg_season_all['Score'] / reg_season_all['Possession'] * reg_season_all['Possessionopponent_Average'] / 100 

reg_season_all['AdjD'] = reg_season_all['OpponentScore'] / reg_season_all['Possession'] * reg_season_all['Possessionopponent_Average'] / 100 

reg_season_all['AdjEM'] = reg_season_all['AdjO']  - reg_season_all['AdjD'] 

reg_season_all['EWP'] = reg_season_all['AdjO'] ** 11.5  / (reg_season_all['AdjO'] **11.5 + reg_season_all['AdjD']**11.5)

# %%
reg_season_all = reg_season_all.drop('OpponentTeamID',axis=1)

# %%
reg_season_all.columns
# Out:
# Index(['Season', 'TeamID', 'wins', 'Score', 'OpponentScore', 'OR',
#        'OpponentOR', 'TOmargin', 'FG', 'FGopponent', 'FG3', 'FG3opponent',
#        'FT', 'Possession', 'Possessionopponent', 'Possession_Average',
#        'Possessionopponent_Average', 'AdjO', 'AdjD', 'AdjEM', 'EWP'],
#       dtype='object')

# %%
reg_season_means = reg_season_all.groupby(['TeamID','Season']).mean().reset_index()

# %%
reg_season_means = reg_season_means.drop(['wins'], axis=1)

# %%
reg_season_sum = reg_season_all.groupby(['TeamID','Season']).sum().reset_index()

# %%
reg_season_sum = reg_season_sum.drop(['Score','OpponentScore','TOmargin','FG','FG3','FGopponent','FG3opponent','FT',
                                      'OR','OpponentOR',
                                      'Possession','Possessionopponent','Possession_Average','Possessionopponent_Average','AdjO','AdjD','AdjEM','EWP'], axis=1)

# %%
regseason_df = pd.merge(reg_season_means, reg_season_sum, left_on=['TeamID','Season'], right_on = ['TeamID','Season'], how='left')

# %%
regseason_df.head()
# Out:
#    TeamID  Season  Score  OpponentScore   OR  OpponentOR  TOmargin   FG  \
# 0    1101    2014  63.14          78.62 8.00       10.38      2.86 0.41
# 1    1101    2015  61.00          71.86 8.25       10.04     -0.64 0.41
# 2    1101    2016  69.85          76.26 8.19        8.59     -0.04 0.44
# 3    1101    2017  67.88          72.64 7.56       10.64     -0.32 0.46
# 4    1101    2018  70.67          72.81 9.04        9.93     -1.07 0.45
#
#    FGopponent  FG3  ...   FT  Possession  Possessionopponent  \
# 0        0.51 0.38  ... 0.76       63.81               63.88
# 1        0.49 0.38  ... 0.74       61.52               61.71
# 2        0.49 0.36  ... 0.70       65.97               66.72
# 3        0.46 0.37  ... 0.64       65.67               65.58
# 4        0.46 0.33  ... 0.71       67.26               67.36
#
#    Possession_Average  Possessionopponent_Average  AdjO  AdjD  AdjEM  EWP  \
# 0               63.81                       65.24  0.64  0.81  -0.16 0.18
# 1               61.52                       63.58  0.63  0.74  -0.11 0.29
# 2               65.97                       67.35  0.71  0.78  -0.07 0.37
# 3               65.67                       67.41  0.70  0.75  -0.05 0.38
# 4               67.26                       67.91  0.72  0.74  -0.02 0.45
#
#    wins
# 0     2
# 1     7
# 2     9
# 3     9
# 4    12
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Tourney results
#
# > This file identifies the game-by-game NCAA® tournament results for all seasons of historical data. The data is formatted exactly like the MRegularSeasonCompactResults data. All games will show up as neutral site (so WLoc is always N). Note that this tournament game data also includes the play-in games (which always occurred on day 134/135) for those years that had play-in games. Thus each season you will see between 63 and 67 games listed, depending on how many play-in games there were.

# %%
df_tourney_results = pd.concat([
    pd.read_csv(DATA_PATH + "WNCAATourneyCompactResults.csv"),
    pd.read_csv(DATA_PATH + "MNCAATourneyCompactResults.csv"),
], ignore_index=True)
df_tourney_results.drop(['NumOT', 'WLoc'], axis=1, inplace=True)

# %%
df_tourney_results
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore
# 0       1998     137     3104      94     3422      46
# 1       1998     137     3112      75     3365      63
# 2       1998     137     3163      93     3193      52
# 3       1998     137     3198      59     3266      45
# 4       1998     137     3203      74     3208      72
# ...      ...     ...      ...     ...      ...     ...
# 3895    2022     146     1242      76     1274      50
# 3896    2022     146     1314      69     1389      49
# 3897    2022     152     1242      81     1437      65
# 3898    2022     152     1314      81     1181      77
# 3899    2022     154     1242      72     1314      69
#
# [3900 rows x 6 columns]

# %% [markdown]
# ## FiveThirtyEight Ratings
# > Not available yet !

# %%
# df_538 = pd.read_csv("../input/ncaa-men-538-team-ratings/538ratingsMen.csv")
# df_538.drop('TeamName', axis=1, inplace=True)
# df_538.head()

# %% [markdown]
# ## Kenpom

# %% [markdown]
# Kenpom 정보를 크롤링했으나 남자팀만 존재하여 실제로는 Kenpom의 공식에 따라 값을 구하였음. 구하는 방법이 일부 틀릴 수 있음 (특히 Lucky)

# %% [markdown]
# https://github.com/harmkenn/Python_Madness_2023/blob/58ed1e5876817bf4e65ba4bf05b59fb3fa1e4cfd/notebooks/step01_aScrapeKenPom.ipynb

# %%
# # Grab KenPom 2008 to 2022

# from urllib.request import Request, urlopen
# from bs4 import BeautifulSoup
# import pandas as pd
# import numpy as np
# from tqdm import tqdm

# season = np.arange(2008,2023,1)
# allkp = pd.DataFrame(columns = ['Year','Team','Conf','AdjEM','AdjO','AdjD','AdjT','SOSEM','SOSO','SOSD'])
# for y in season:
#     req = Request(
#         url=f'https://kenpom.com/index.php?y={y}', 
#         headers={'User-Agent': 'Mozilla/5.0'}
#     )
#     webpage = urlopen(req).read()
#     soup =BeautifulSoup(webpage, 'html.parser')

#     table = soup.find('table', class_=None)
    
#     for row in tqdm(table.tbody.find_all('tr')):    
#         # Find all data for each column
#         columns = row.find_all('td')
        
#         if(columns != []):
            
#             Team = columns[1].text.strip()
#             Conf = columns[2].text.strip()
            
#             AdjEM = columns[4].text.strip()
#             AdjO = columns[5].text.strip()
#             AdjD = columns[7].text.strip()
#             AdjT = columns[9].text.strip()
#             SOSEM = columns[13].text.strip()
#             SOSO = columns[15].text.strip()
#             SOSD = columns[17].text.strip()
#             newrow = [y,Team,Conf,AdjEM,AdjO,AdjD,AdjT,SOSEM,SOSO,SOSD]
#             allkp.loc[len(allkp)]=newrow
#             #newrow = pd.DataFrame({'Year':2008,'Team': Team,'Conf':Conf,'AdjEM':AdjEM,'AdjO':AdjO,'AdjD':AdjD,'AdjT':AdjT,'SOSEM':SOSEM,'SOSO':SOSO,'SOSD':SOSD})
#             #allkp = pd.concat(allkp,newrow)
#             allkp['Team'] = allkp['Team'].str.replace('\d+','',regex=True).str.replace('*','',regex=True).str.rstrip()

# allkp.to_csv('step01_kenpom0823.csv',index=False)

# %%
# # Grab KenPom 2023

# from urllib.request import Request, urlopen
# from bs4 import BeautifulSoup
# import pandas as pd
# import numpy as np


# allkp = pd.read_csv('step01_kenpom0823.csv')
# allkp = allkp[allkp['Year']!=2023]
# y = 2023

# req = Request(
#     url=f'https://kenpom.com/index.php?y={y}', 
#     headers={'User-Agent': 'Mozilla/5.0'}
# )
# webpage = urlopen(req).read()
# soup =BeautifulSoup(webpage, 'html.parser')

# table = soup.find('table', class_=None)

# for row in table.tbody.find_all('tr'):    
#     # Find all data for each column
#     columns = row.find_all('td')
    
#     if(columns != []):
        
#         Team = columns[1].text.strip()
#         Conf = columns[2].text.strip()
        
#         AdjEM = columns[4].text.strip()
#         AdjO = columns[5].text.strip()
#         AdjD = columns[7].text.strip()
#         AdjT = columns[9].text.strip()
#         SOSEM = columns[13].text.strip()
#         SOSO = columns[15].text.strip()
#         SOSD = columns[17].text.strip()
#         newrow = [y,Team,Conf,AdjEM,AdjO,AdjD,AdjT,SOSEM,SOSO,SOSD]
#         allkp.loc[len(allkp)]=newrow
#         #newrow = pd.DataFrame({'Year':2008,'Team': Team,'Conf':Conf,'AdjEM':AdjEM,'AdjO':AdjO,'AdjD':AdjD,'AdjT':AdjT,'SOSEM':SOSEM,'SOSO':SOSO,'SOSD':SOSD})
#         #allkp = pd.concat(allkp,newrow)
#         allkp['Team'] = allkp['Team'].str.replace('\d+','',regex=True).str.replace('*','',regex=True).str.rstrip()


# allkp.to_csv('step01_kenpom0823.csv',index=False)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Train data

# %%
# 여자부의 능력치가 있는 2013년 이후를 대상으로 모델 만들기

df = df_tourney_results.copy()
df = df[df['Season'] >= 2001].reset_index(drop=True)

df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore
# 0    2001     137     3155      51     3151      49
# 1    2001     137     3196      84     3221      52
# 2    2001     137     3199      72     3408      70
# 3    2001     137     3208      77     3251      48
# 4    2001     137     3235     100     3224      61

# %% [markdown]
# ### Seeds
# - `SeedW` is the seed of the winning team
# - `SeedL` is the seed of the losing team

# %%
df = pd.merge(
    df, 
    df_seeds, 
    how='left', 
    left_on=['Season', 'WTeamID'], 
    right_on=['Season', 'TeamID']
).drop('TeamID', axis=1).rename(columns={'Seed': 'SeedW'})

# %%
df = pd.merge(
    df, 
    df_seeds, 
    how='left', 
    left_on=['Season', 'LTeamID'], 
    right_on=['Season', 'TeamID']
).drop('TeamID', axis=1).rename(columns={'Seed': 'SeedL'})

# %%
def treat_seed(seed):
    return int(re.sub("[^0-9]", "", seed))

df['SeedW'] = df['SeedW'].apply(treat_seed)
df['SeedL'] = df['SeedL'].apply(treat_seed)

# %%
df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore  SeedW  SeedL
# 0    2001     137     3155      51     3151      49      5     12
# 1    2001     137     3196      84     3221      52      3     14
# 2    2001     137     3199      72     3408      70      7     10
# 3    2001     137     3208      77     3251      48      2     15
# 4    2001     137     3235     100     3224      61      2     15

# %% [markdown]
# ### Season Stats
# - `WinRatioW` is the win ratio of the winning team during the season
# - `WinRatioL` is the win ratio of the losing team during the season

# %%
df = pd.merge(
    df,
    df_features_season,
    how='left',
    left_on=['Season', 'WTeamID'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsW',
    'NumLosses': 'NumLossesW',
    'GapWins': 'GapWinsW',
    'GapLosses': 'GapLossesW',
    'WinRatio': 'WinRatioW',
    'GapAvg': 'GapAvgW',
    'WinRatio_3years': 'WinRatio_3yearsW',
    'GapAvg_3years': 'GapAvg_3yearsW',
    'TourneyY_3years':'TourneyY_3yearsW'
}).drop(columns='TeamID', axis=1)

# %%
df = pd.merge(
    df,
    df_features_season,
    how='left',
    left_on=['Season', 'LTeamID'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsL',
    'NumLosses': 'NumLossesL',
    'GapWins': 'GapWinsL',
    'GapLosses': 'GapLossesL',
    'WinRatio': 'WinRatioL',
    'GapAvg': 'GapAvgL',
    'WinRatio_3years': 'WinRatio_3yearsL',
    'GapAvg_3years': 'GapAvg_3yearsL',
    'TourneyY_3years':'TourneyY_3yearsL',
}).drop(columns='TeamID', axis=1)

# %% [markdown]
# ### Season Stats detail

# %%
df = pd.merge(
    df,
    regseason_df,
    how='left',
    left_on=['Season', 'WTeamID'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'TOmargin': 'TOmarginW',
    'FG': 'FGW',
    'FGopponent': 'FGopponentW',
    'FG3': 'FG3W',
    'FG3opponent': 'FG3opponentW',
    'FT': 'FTW',
    'AdjO':'AdjOW',
    'AdjD':'AdjDW',
    'AdjEM':'AdjEMW',
    'EWP':'EWPW',
    'Possession':'PossessionW',
}).drop(columns='TeamID', axis=1)

# %%
df = pd.merge(
    df,
    regseason_df,
    how='left',
    left_on=['Season', 'LTeamID'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'TOmargin': 'TOmarginL',
    'FG': 'FGL',
    'FGopponent': 'FGopponentL',
    'FG3': 'FG3L',
    'FG3opponent': 'FG3opponentL',
    'FT': 'FTL',
    'AdjO':'AdjOL',
    'AdjD':'AdjDL',
    'AdjEM':'AdjEML',
    'EWP':'EWPL',
    'Possession':'PossessionL',
}).drop(columns='TeamID', axis=1)

# %% [markdown]
# ### FiveThirtyEight Ratings
# - `538ratingW` is the rating of the winning team during the season
# - `538ratingL` is the rating of the losing team during the season

# %%
# df = pd.merge(
#     df,
#     df_538,
#     how='left',
#     left_on=['Season', 'WTeamID'],
#     right_on=['Season', 'TeamID']
# ).drop('TeamID', axis=1).rename(columns={'538rating': '538ratingW'})

# %%
# df = pd.merge(
#     df, 
#     df_538, 
#     how='left', 
#     left_on=['Season', 'LTeamID'], 
#     right_on=['Season', 'TeamID']
# ).drop('TeamID', axis=1).rename(columns={'538rating': '538ratingL'})

# %%
# df.head()

# %% [markdown]
# ### Add symetrical
# - Right now our data only consists of won matches
# - We duplicate our data, get rid of the winner loser

# %%
def add_loosing_matches(df):
    win_rename = {
        "WTeamID": "TeamIdA", 
        "WScore" : "ScoreA", 
        "LTeamID" : "TeamIdB",
        "LScore": "ScoreB",
     }
    win_rename.update({c : c[:-1] + "A" for c in df.columns if c.endswith('W')})
    win_rename.update({c : c[:-1] + "B" for c in df.columns if c.endswith('L')})
    
    lose_rename = {
        "WTeamID": "TeamIdB", 
        "WScore" : "ScoreB", 
        "LTeamID" : "TeamIdA",
        "LScore": "ScoreA",
    }
    lose_rename.update({c : c[:-1] + "B" for c in df.columns if c.endswith('W')})
    lose_rename.update({c : c[:-1] + "A" for c in df.columns if c.endswith('L')})
    
    win_df = df.copy()
    lose_df = df.copy()
    
    win_df = win_df.rename(columns=win_rename)
    lose_df = lose_df.rename(columns=lose_rename)
    
    return pd.concat([win_df, lose_df], axis=0, sort=False)

# %%
df = add_loosing_matches(df)

# %% [markdown]
# ### Differences
# - We compute the difference between the team for each feature.
# - This helps further assessing how better (or worse) team A is from team B

# %%
cols_to_diff = [
    'Seed', 'WinRatio', 'GapAvg', # '538rating'
    'FG','FG3','FT','TOmargin', # Custom stat
    'WinRatio_3years', 'GapAvg_3years','TourneyY_3years',
    'AdjO','AdjD','AdjEM',
    'Possession'
]

for col in cols_to_diff:
    df[col + 'Diff'] = df[col + 'A'] - df[col + 'B']

# %% [markdown]
# ## Test Data

# %% [markdown]
# ### Preparing

# %%
df_test = pd.read_csv(DATA_PATH + "SampleSubmission2023.csv")

# %%
df_test['Season'] = df_test['ID'].apply(lambda x: int(x.split('_')[0]))
df_test['TeamIdA'] = df_test['ID'].apply(lambda x: int(x.split('_')[1]))
df_test['TeamIdB'] = df_test['ID'].apply(lambda x: int(x.split('_')[2]))

# %%
df_test
# Out:
#                     ID  Pred  Season  TeamIdA  TeamIdB
# 0       2023_1101_1102  0.50    2023     1101     1102
# 1       2023_1101_1103  0.50    2023     1101     1103
# 2       2023_1101_1104  0.50    2023     1101     1104
# 3       2023_1101_1105  0.50    2023     1101     1105
# 4       2023_1101_1106  0.50    2023     1101     1106
# ...                ...   ...     ...      ...      ...
# 130678  2023_3474_3476  0.50    2023     3474     3476
# 130679  2023_3474_3477  0.50    2023     3474     3477
# 130680  2023_3475_3476  0.50    2023     3475     3476
# 130681  2023_3475_3477  0.50    2023     3475     3477
# 130682  2023_3476_3477  0.50    2023     3476     3477
#
# [130683 rows x 5 columns]

# %% [markdown]
# ### Seeds
# - Seeds are not released yet, so I fill missing values with "W01"

# %%
df_test = pd.merge(
    df_test,
    df_seeds,
    how='left',
    left_on=['Season', 'TeamIdA'],
    right_on=['Season', 'TeamID']
).drop('TeamID', axis=1).rename(columns={'Seed': 'SeedA'}).fillna('W01')

# %%
df_test = pd.merge(
    df_test, 
    df_seeds, 
    how='left', 
    left_on=['Season', 'TeamIdB'], 
    right_on=['Season', 'TeamID']
).drop('TeamID', axis=1).rename(columns={'Seed': 'SeedB'}).fillna('W01')

# %%
df_test['SeedA'] = df_test['SeedA'].apply(treat_seed)
df_test['SeedB'] = df_test['SeedB'].apply(treat_seed)

# %% [markdown]
# ### Season Stats

# %%
df_test = pd.merge(
    df_test,
    df_features_season,
    how='left',
    left_on=['Season', 'TeamIdA'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsA',
    'NumLosses': 'NumLossesA',
    'GapWins': 'GapWinsA',
    'GapLosses': 'GapLossesA',
    'WinRatio': 'WinRatioA',
    'GapAvg': 'GapAvgA',
    'WinRatio_3years': 'WinRatio_3yearsA',
    'GapAvg_3years': 'GapAvg_3yearsA',
    'TourneyY_3years':'TourneyY_3yearsA'
}).drop(columns='TeamID', axis=1)

# %%
df_test = pd.merge(
    df_test,
    df_features_season,
    how='left',
    left_on=['Season', 'TeamIdB'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'NumWins': 'NumWinsB',
    'NumLosses': 'NumLossesB',
    'GapWins': 'GapWinsB',
    'GapLosses': 'GapLossesB',
    'WinRatio': 'WinRatioB',
    'GapAvg': 'GapAvgB',
    'WinRatio_3years': 'WinRatio_3yearsB',
    'GapAvg_3years': 'GapAvg_3yearsB',
    'TourneyY_3years':'TourneyY_3yearsB'
}).drop(columns='TeamID', axis=1)

# %% [markdown]
# #### Season detail

# %%
df_test = pd.merge(
    df_test,
    regseason_df,
    how='left',
    left_on=['Season', 'TeamIdA'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'TOmargin': 'TOmarginA',
    'FG': 'FGA',
    'FGopponent': 'FGopponentA',
    'FG3': 'FG3A',
    'FG3opponent': 'FG3opponentA',
    'FT': 'FTA',
    'AdjO':'AdjOA',
    'AdjD':'AdjDA',
    'AdjEM':'AdjEMA',
    'EWP':'EWPA',
    'Possession':'PossessionA',
}).drop(columns='TeamID', axis=1)

# %%
df_test = pd.merge(
    df_test,
    regseason_df,
    how='left',
    left_on=['Season', 'TeamIdB'],
    right_on=['Season', 'TeamID']
).rename(columns={
    'TOmargin': 'TOmarginB',
    'FG': 'FGB',
    'FGopponent': 'FGopponentB',
    'FG3': 'FG3B',
    'FG3opponent': 'FG3opponentB',
    'FT': 'FTB',
    'AdjO':'AdjOB',
    'AdjD':'AdjDB',
    'AdjEM':'AdjEMB',
    'EWP':'EWPB',
    'Possession':'PossessionB',
}).drop(columns='TeamID', axis=1)

# %% [markdown]
# ### Ratings

# %%
# df_test = pd.merge(
#     df_test,
#     df_538,
#     how='left',
#     left_on=['Season', 'TeamIdA'],
#     right_on=['Season', 'TeamID']
# ).drop('TeamID', axis=1).rename(columns={'538rating': '538ratingA'})

# %%
# df_test = pd.merge(
#     df_test,
#     df_538,
#     how='left',
#     left_on=['Season', 'TeamIdB'],
#     right_on=['Season', 'TeamID']
# ).drop('TeamID', axis=1).rename(columns={'538rating': '538ratingB'})

# %% [markdown]
# ### Differences

# %%
for col in cols_to_diff:
    df_test[col + 'Diff'] = df_test[col + 'A'] - df_test[col + 'B']

# %% [markdown]
# ## Target

# %%
df['ScoreDiff'] = df['ScoreA'] - df['ScoreB']
df['WinA'] = (df['ScoreDiff'] > 0).astype(int)

# %%
df['LuckyA'] = df['WinRatioA'] - df['EWPA']

df['LuckyB'] = df['WinRatioB'] - df['EWPB']

df['LuckyDiff'] = df['LuckyA'] -df['LuckyB']

# %%
df_test['LuckyA'] = df_test['WinRatioA'] - df_test['EWPA']

df_test['LuckyB'] = df_test['WinRatioB'] - df_test['EWPB']

df_test['LuckyDiff'] = df_test['LuckyA'] -df_test['LuckyB']

# %%
df
# Out:
#       Season  DayNum  TeamIdA  ScoreA  TeamIdB  ScoreB  SeedA  SeedB  \
# 0       2001     137     3155      51     3151      49      5     12
# 1       2001     137     3196      84     3221      52      3     14
# 2       2001     137     3199      72     3408      70      7     10
# 3       2001     137     3208      77     3251      48      2     15
# 4       2001     137     3235     100     3224      61      2     15
# ...      ...     ...      ...     ...      ...     ...    ...    ...
# 2698    2022     146     1274      50     1242      76     10      1
# 2699    2022     146     1389      49     1314      69     15      8
# 2700    2022     152     1437      65     1242      81      2      1
# 2701    2022     152     1181      77     1314      81      2      8
# 2702    2022     154     1314      69     1242      72      8      1
#
#       NumWinsA  NumLossesA  ...  TourneyY_3yearsDiff  AdjODiff  AdjDDiff  \
# 0        20.00        9.00  ...                 0.00       NaN       NaN
# 1        23.00        5.00  ...                 0.00       NaN       NaN
# 2        18.00       11.00  ...                 0.00       NaN       NaN
# 3        26.00        5.00  ...                 0.00       NaN       NaN
# 4        25.00        5.00  ...                 0.00       NaN       NaN
# ...        ...         ...  ...                  ...       ...       ...
# 2698     23.00       10.00  ...                -2.00     -0.02      0.05
# 2699     18.00       11.00  ...                -3.00     -0.06     -0.05
# 2700     26.00        7.00  ...                 0.00      0.03      0.02
# 2701     28.00        6.00  ...                -1.00      0.06     -0.02
# 2702     24.00        9.00  ...                 0.00     -0.02      0.02
#
#       AdjEMDiff  PossessionDiff  ScoreDiff  WinA  LuckyA  LuckyB  LuckyDiff
# 0           NaN             NaN          2     1     NaN     NaN        NaN
# 1           NaN             NaN         32     1     NaN     NaN        NaN
# 2           NaN             NaN          2     1     NaN     NaN        NaN
# 3           NaN             NaN         29     1     NaN     NaN        NaN
# 4           NaN             NaN         39     1     NaN     NaN        NaN
# ...         ...             ...        ...   ...     ...     ...        ...
# 2698      -0.06           -2.13        -26     0    0.08    0.09      -0.00
# 2699      -0.01           -3.27        -20     0    0.01    0.06      -0.05
# 2700       0.01           -5.49        -16     0    0.08    0.09      -0.01
# 2701       0.07           -2.04         -4     0    0.05    0.06      -0.01
# 2702      -0.04            0.75         -3     0    0.06    0.09      -0.03
#
# [5406 rows x 85 columns]

# %% [markdown]
# # Modeling

# %% [markdown]
# #### Baseline

# %%
features = [
    'SeedA', 'SeedB',
    'SeedDiff',
    'WinRatioA', 'WinRatioB',
    'WinRatioDiff', 
    'GapAvgA', 'GapAvgB',
    'GapAvgDiff',
    #'FGDiff',
    #'FGA','FGB',
    #'FG3Diff',
    #'FG3A','FG3B',
    #'FTDiff',
    #'FTA','FTB',
    #'TOmarginDiff',
    #'TOmarginA','TOmarginB'
]

# %%
# A하고 B 둘 중에 하나만 들어가야할 것 같음. 둘이 사실상 같은 변수임임

features = [
    #'SeedA', #'SeedB',
    'SeedDiff',
    'WinRatioA', 'WinRatioB',
    'WinRatioDiff', 
    'GapAvgA', #'GapAvgB',
    'GapAvgDiff',
    'FGDiff',
    'FGA','FGB',
    'FG3Diff',
    'FG3A','FG3B',
    'FTDiff',
    'FTA','FTB',
    'TOmarginDiff',
    'TOmarginA','TOmarginB',
    'WinRatio_3yearsA', 'WinRatio_3yearsB',
    'WinRatio_3yearsDiff', 
    'GapAvg_3yearsA', 'GapAvg_3yearsB',
    'GapAvg_3yearsDiff',
    'AdjOA','AdjOB',
    'AdjODiff',
    'AdjDA', 'AdjDB',
    'AdjDDiff',
    'AdjEMA', 'AdjEMB',
    'AdjEMDiff',
    'LuckyA', 'LuckyB',
    'LuckyDiff',
    'TourneyY_3yearsA','TourneyY_3yearsB',
    'TourneyY_3yearsDiff',
]

# %%
# A하고 B 둘 중에 하나만 들어가야할 것 같음. 둘이 사실상 같은 변수임임

features = [
    #'SeedA', 'SeedB',
    'SeedDiff',
    #'WinRatioA', 'WinRatioB',
    'WinRatioDiff', 
    #'GapAvgA', #'GapAvgB',
    'GapAvgDiff',
    'FGDiff',
    #'FGA','FGB',
    'FG3Diff',
    #'FG3A','FG3B',
    'FTDiff',
    #'FTA','FTB',
    'TOmarginDiff',
    #'TOmarginA','TOmarginB',
    #'WinRatio_3yearsA', 'WinRatio_3yearsB',
    'WinRatio_3yearsDiff', 
    #'GapAvg_3yearsA', 'GapAvg_3yearsB',
    'GapAvg_3yearsDiff',
    #'AdjOA','AdjOB',
    'AdjODiff',
    #'AdjDA', 'AdjDB',
    'AdjDDiff',
    #'AdjEMA', 'AdjEMB',
    'AdjEMDiff',
    #'LuckyA', 'LuckyB',
    'LuckyDiff',
    'TourneyY_3yearsA','TourneyY_3yearsB',
    'TourneyY_3yearsDiff',
]

# %%
def rescale(features, df_train, df_val, df_test=None):
    min_ = df_train[features].min()
    max_ = df_train[features].max()
    
    df_train[features] = (df_train[features] - min_) / (max_ - min_)
    df_val[features] = (df_val[features] - min_) / (max_ - min_)
    
    if df_test is not None:
        df_test[features] = (df_test[features] - min_) / (max_ - min_)
        
    return df_train, df_val, df_test

# %% [markdown]
# ### Cross Validation
# - Validate on season `n`, for `n` in the 3 last seasons.
# - Train on earlier seasons. First available season is 2016 because of the FiveThirtyEight ratings.
# - Pipeline support classification (predict the team that wins) and regression (predict the score gap), but classification worked better on CV.

# %% [markdown]
# ### Baseline은 엘라스틱넷 회귀, 로지스틱 회귀

# %%
def kfold(df, df_test_=None, plot=False, verbose=0, mode="reg"):
    seasons = df['Season'].unique()
    cvs = []
    pred_tests = []
    target = "ScoreDiff" if mode == "reg" else "WinA"
    
    for season in seasons[1:]:
        if verbose:
            print(f'\nValidating on season {season}')
        
        df_train = df[df['Season'] < season].reset_index(drop=True).copy()
        df_val = df[df['Season'] == season].reset_index(drop=True).copy()
        df_test = df_test_.copy()
        
        df_train, df_val, df_test = rescale(features, df_train, df_val, df_test)
        
        if mode == "reg":
#             model = LinearRegression()
            model = ElasticNet(alpha=1, l1_ratio=0.5)
        else:
            model = LogisticRegression(C=1)

        model.fit(df_train[features], df_train[target])
        
        if mode == "reg":
            pred = model.predict(df_val[features])
        else:
            pred = model.predict_proba(df_val[features])[:, 1]
        
        if df_test is not None:
            if mode == "reg":
                pred_test = model.predict(df_test[features])
                
#                 print( pred_test.max() - pred_test.min())
                pred_test = (pred_test - pred_test.min()) / (pred_test.max() - pred_test.min())
            else:
                pred_test = model.predict_proba(df_test[features])[:, 1]
                
            pred_tests.append(pred_test)
            
        if plot:
            plt.figure(figsize=(15, 6))
            plt.subplot(1, 2, 1)
            plt.scatter(pred, df_val['ScoreDiff'].values, s=5)
            plt.title('Prediction vs Score Diff')
            plt.grid(True)
            plt.subplot(1, 2, 2)
            sns.histplot(pred, bins=20)
            plt.title('Predictions probability repartition')
            plt.show()
        
        pred = (pred - pred.min()) / (pred.max() - pred.min())
        pred = np.clip(pred, 0, 1)

        score = ((df_val['WinA'].values - pred) ** 2).mean()
        cvs.append(score)

        if verbose:
            print(f'\t -> Scored {score:.3f}')
        
    print(f'\n Local CV is {np.mean(cvs):.3f}')
    
    return pred_tests, cvs

# %%
pred_tests, cvs = kfold(df[df['Season'] >= 2013], df_test, plot=True, verbose=1, mode="cls")
# Out:
# Validating on season 2014
# 	 -> Scored 0.187
#
# Validating on season 2015
# 	 -> Scored 0.146
#
# Validating on season 2016
# 	 -> Scored 0.178
#
# Validating on season 2017
# 	 -> Scored 0.168
#
# Validating on season 2018
# 	 -> Scored 0.192
#
# Validating on season 2019
# 	 -> Scored 0.155
#
# Validating on season 2021
# 	 -> Scored 0.188
#
# Validating on season 2022
# 	 -> Scored 0.195
#
#  Local CV is 0.176

# %% [markdown]
# ## Submission

# %%
pred_test = np.mean(pred_tests, 0)
df_test['pred'] = pred_test

_ = sns.displot(pred_test)

# %%
final_sub = df_test[['ID', 'pred']].copy()
final_sub.to_csv('submission_baseline_0307.csv', index=False)

# %%
final_sub[final_sub['pred'] < 0.5]
# Out:
#                     ID  pred
# 2       2023_1101_1104  0.48
# 9       2023_1101_1112  0.47
# 13      2023_1101_1116  0.40
# 16      2023_1101_1120  0.47
# 19      2023_1101_1124  0.43
# ...                ...   ...
# 130676  2023_3473_3477  0.34
# 130677  2023_3474_3475  0.29
# 130678  2023_3474_3476  0.37
# 130679  2023_3474_3477  0.36
# 130682  2023_3476_3477  0.48
#
# [65336 rows x 2 columns]

# %% [markdown]
# Done !

# %% [markdown]
# # AutoML

# %% [markdown]
# 여기서부터가 가져온 게 아니라 실제로 만든 것, AutoML로 모델 구축

# %%
# !pip install --use-deprecated=legacy-resolver pycaret[full]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycaret[full]
#   Downloading pycaret-2.3.10-py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.2/320.2 KB 6.0 MB/s eta 0:00:00
# Collecting spacy<2.4.0
#   Downloading spacy-2.3.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 62.1 MB/s eta 0:00:00
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (1.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (3.5.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (3.7)
# Requirement already satisfied: IPython in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (7.9.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (0.11.2)
# Requirement already satisfied: plotly>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (5.5.0)
# Collecting mlflow
#   Downloading mlflow-2.2.1-py3-none-any.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 69.7 MB/s eta 0:00:00
# Collecting pandas-profiling>=2.8.0
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 KB 31.2 MB/s eta 0:00:00
# Collecting pyyaml<6.0.0
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 50.2 MB/s eta 0:00:00
# Requirement already satisfied: yellowbrick>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (1.5)
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp38-cp38-manylinux1_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 88.6 MB/s eta 0:00:00
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (1.8.2.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (7.7.1)
# Collecting imbalanced-learn==0.7.0
#   Downloading imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.1/167.1 KB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: gensim<4.0.0 in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (3.6.0)
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: cufflinks>=0.17.0 in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (0.17.3)
# Collecting lightgbm>=2.3.1
#   Downloading lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 85.3 MB/s eta 0:00:00
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (1.2.0)
# Collecting scipy<=1.5.4
#   Downloading scipy-1.5.4-cp38-cp38-manylinux1_x86_64.whl (25.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 59.9 MB/s eta 0:00:00
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 KB 7.6 MB/s eta 0:00:00
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.0-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 17.1 MB/s eta 0:00:00
# Collecting numba<0.55
#   Downloading numba-0.54.1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 53.4 MB/s eta 0:00:00
# Collecting pyod
#   Downloading pyod-1.0.7.tar.gz (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.7/147.7 KB 17.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: textblob in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (0.15.3)
# Collecting evidently; extra == "full"
#   Downloading evidently-0.2.6-py3-none-any.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 81.2 MB/s eta 0:00:00
# Collecting explainerdashboard; extra == "full"
#   Downloading explainerdashboard-0.4.2.1-py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.9/286.9 KB 27.2 MB/s eta 0:00:00
# Collecting fugue>=0.6.5; extra == "full"
#   Downloading fugue-0.8.1-py3-none-any.whl (364 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 KB 34.0 MB/s eta 0:00:00
# Collecting boto3; extra == "full"
#   Downloading boto3-1.26.85-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.7/134.7 KB 15.1 MB/s eta 0:00:00
# Collecting gradio; extra == "full"
#   Downloading gradio-3.20.1-py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 84.8 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-storage; extra == "full" in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (2.7.0)
# Requirement already satisfied: hyperopt; extra == "full" in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (0.1.2)
# Collecting scikit-optimize>=0.8.1; extra == "full"
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 KB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil; extra == "full" in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (5.4.8)
# Collecting uvicorn; extra == "full"
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 7.0 MB/s eta 0:00:00
# Collecting fairlearn; extra == "full"
#   Downloading fairlearn-0.8.0-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.0/235.0 KB 25.6 MB/s eta 0:00:00
# Collecting fastapi; extra == "full"
#   Downloading fastapi-0.92.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 KB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: xgboost>=1.1.0; extra == "full" in /usr/local/lib/python3.8/dist-packages (from pycaret[full]) (1.7.4)
# Collecting catboost>=0.23.2; extra == "full"
#   Downloading catboost-1.1.1-cp38-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 7.9 MB/s eta 0:00:00
# Collecting tune-sklearn>=0.2.1; extra == "full"
#   Downloading tune_sklearn-0.4.5-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 KB 4.8 MB/s eta 0:00:00
# Collecting optuna>=2.2.0; extra == "full"
#   Downloading optuna-3.1.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 36.4 MB/s eta 0:00:00
# Collecting ray[tune]>=1.0.0; extra == "full"
#   Downloading ray-2.3.0-cp38-cp38-manylinux2014_x86_64.whl (58.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 24.6 MB/s eta 0:00:00
# Collecting shap; extra == "full"
#   Downloading shap-0.41.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.9/575.9 KB 49.0 MB/s eta 0:00:00
# Collecting interpret<=0.2.4; extra == "full"
#   Downloading interpret-0.2.4-py3-none-any.whl (1.4 kB)
# Collecting autoviz; extra == "full"
#   Downloading autoviz-0.1.58-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 KB 7.7 MB/s eta 0:00:00
# Collecting m2cgen; extra == "full"
#   Downloading m2cgen-0.10.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 KB 13.0 MB/s eta 0:00:00
# Collecting azure-storage-blob; extra == "full"
#   Downloading azure_storage_blob-12.15.0-py3-none-any.whl (387 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.8/387.8 KB 38.0 MB/s eta 0:00:00
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0->pycaret[full]) (0.7.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0->pycaret[full]) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0->pycaret[full]) (57.4.0)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0->pycaret[full]) (3.0.8)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 KB 22.9 MB/s eta 0:00:00
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0->pycaret[full]) (2.25.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0->pycaret[full]) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0->pycaret[full]) (1.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0->pycaret[full]) (4.64.1)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<2.4.0->pycaret[full]) (1.22.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->pycaret[full]) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->pycaret[full]) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pycaret[full]) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pycaret[full]) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pycaret[full]) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pycaret[full]) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pycaret[full]) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pycaret[full]) (0.11.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->pycaret[full]) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->pycaret[full]) (2022.6.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from IPython->pycaret[full]) (2.0.10)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.8/dist-packages (from IPython->pycaret[full]) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from IPython->pycaret[full]) (5.7.1)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 80.4 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from IPython->pycaret[full]) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from IPython->pycaret[full]) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from IPython->pycaret[full]) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from IPython->pycaret[full]) (0.7.5)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from plotly>=4.4.1->pycaret[full]) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly>=4.4.1->pycaret[full]) (8.2.2)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (0.4)
# Collecting gunicorn<21; platform_system != "Windows"
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (6.0.0)
# Requirement already satisfied: Jinja2<4,>=2.11; platform_system != "Windows" in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (3.1.2)
# Requirement already satisfied: pyarrow<12,>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (9.0.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (0.4.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (1.4.46)
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 KB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (2.2.1)
# Collecting querystring-parser<2
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (2.2.3)
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks-cli-0.17.4.tar.gz (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 KB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (3.19.6)
# Collecting gitpython<4,>=2.1.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.8/dist-packages (from mlflow->pycaret[full]) (3.4.1)
# Collecting alembic<2
#   Downloading alembic-1.10.1-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 22.4 MB/s eta 0:00:00
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.0.0-py2.py3-none-any.whl (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.5/344.5 KB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn==0.23.2->pycaret[full]) (3.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->pycaret[full]) (5.3.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->pycaret[full]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->pycaret[full]) (3.6.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.8/dist-packages (from ipywidgets->pycaret[full]) (3.0.5)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.8/dist-packages (from gensim<4.0.0->pycaret[full]) (6.3.0)
# Requirement already satisfied: colorlover>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from cufflinks>=0.17.0->pycaret[full]) (0.3.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from lightgbm>=2.3.1->pycaret[full]) (0.38.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 66.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numexpr in /usr/local/lib/python3.8/dist-packages (from pyLDAvis->pycaret[full]) (2.8.4)
# Collecting funcy
#   Downloading funcy-1.18-py2.py3-none-any.whl (33 kB)
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp38-cp38-manylinux2014_x86_64.whl (26.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.3/26.3 MB 51.3 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.8/dist-packages (from pyod->pycaret[full]) (0.13.5)
# Collecting graphviz>=0.18.2
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 KB 5.3 MB/s eta 0:00:00
# Collecting jupyter-dash>=0.4.1
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting dash>=2.3.1
#   Downloading dash-2.8.1-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 104.6 MB/s eta 0:00:00
# Collecting dash-bootstrap-components>=1
#   Downloading dash_bootstrap_components-1.4.0-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.9/219.9 KB 22.8 MB/s eta 0:00:00
# Collecting dash-auth
#   Downloading dash_auth-1.4.1.tar.gz (470 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.0/471.0 KB 40.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dtreeviz>=2.1
#   Downloading dtreeviz-2.2.0-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 KB 9.5 MB/s eta 0:00:00
# Collecting flask-simplelogin
#   Downloading flask_simplelogin-0.1.1-py3-none-any.whl (7.2 kB)
# Collecting waitress
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 KB 6.9 MB/s eta 0:00:00
# Collecting oyaml
#   Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Collecting qpd>=0.4.0
#   Downloading qpd-0.4.0-py3-none-any.whl (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.8/187.8 KB 20.8 MB/s eta 0:00:00
# Collecting adagio>=0.2.4
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Collecting triad>=0.8.1
#   Downloading triad-0.8.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 KB 7.9 MB/s eta 0:00:00
# Collecting sqlglot
#   Downloading sqlglot-11.3.0-py3-none-any.whl (234 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.8/234.8 KB 24.7 MB/s eta 0:00:00
# Collecting fugue-sql-antlr>=0.1.5
#   Downloading fugue-sql-antlr-0.1.5.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 KB 18.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.30.0,>=1.29.85
#   Downloading botocore-1.29.85-py3-none-any.whl (10.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 106.5 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 9.7 MB/s eta 0:00:00
# Collecting markdown-it-py[linkify]>=2.0.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 10.9 MB/s eta 0:00:00
# Collecting orjson
#   Downloading orjson-3.8.7-cp38-cp38-manylinux_2_28_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.7/140.7 KB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from gradio; extra == "full"->pycaret[full]) (1.10.5)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.8/dist-packages (from gradio; extra == "full"->pycaret[full]) (2.1.2)
# Collecting mdit-py-plugins<=0.3.3
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from gradio; extra == "full"->pycaret[full]) (4.2.2)
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 5.7 MB/s eta 0:00:00
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from gradio; extra == "full"->pycaret[full]) (3.8.4)
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 9.0 MB/s eta 0:00:00
# Collecting pycryptodome
#   Downloading pycryptodome-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 88.6 MB/s eta 0:00:00
# Collecting aiofiles
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from gradio; extra == "full"->pycaret[full]) (2023.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from gradio; extra == "full"->pycaret[full]) (4.5.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage; extra == "full"->pycaret[full]) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage; extra == "full"->pycaret[full]) (2.4.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage; extra == "full"->pycaret[full]) (2.11.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-storage; extra == "full"->pycaret[full]) (2.16.1)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from hyperopt; extra == "full"->pycaret[full]) (0.16.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from hyperopt; extra == "full"->pycaret[full]) (3.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.8/dist-packages (from hyperopt; extra == "full"->pycaret[full]) (4.3.3)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 7.0 MB/s eta 0:00:00
# Collecting starlette<0.26.0,>=0.25.0
#   Downloading starlette-0.25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 7.7 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (4.3.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (1.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (3.9.0)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.20.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 95.2 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (1.3.1)
# Requirement already satisfied: grpcio>=1.32.0; python_version < "3.10" and sys_platform != "darwin" in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (1.51.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (22.2.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (1.3.3)
# Collecting tensorboardX>=1.9; extra == "tune"
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: tabulate; extra == "tune" in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (0.8.10)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]>=0.2.4
#   Downloading interpret_core-0.3.0-py3-none-any.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 90.2 MB/s eta 0:00:00
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting panel~=0.12.6
#   Downloading panel-0.12.7-py2.py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: xlrd in /usr/local/lib/python3.8/dist-packages (from autoviz; extra == "full"->pycaret[full]) (1.2.0)
# Collecting pyamg
#   Downloading pyamg-4.2.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 82.4 MB/s eta 0:00:00
# Requirement already satisfied: holoviews>=1.14.6 in /usr/local/lib/python3.8/dist-packages (from autoviz; extra == "full"->pycaret[full]) (1.14.9)
# Collecting hvplot>=0.7.3
#   Downloading hvplot-0.8.2-py2.py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 87.7 MB/s eta 0:00:00
# Collecting emoji
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 KB 23.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: bokeh>=2.4.2 in /usr/local/lib/python3.8/dist-packages (from autoviz; extra == "full"->pycaret[full]) (2.4.3)
# Collecting cryptography>=2.1.4
#   Downloading cryptography-39.0.2-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 102.5 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.26.0
#   Downloading azure_core-1.26.3-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.5/174.5 KB 19.3 MB/s eta 0:00:00
# Collecting isodate>=0.6.1
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret[full]) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret[full]) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret[full]) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret[full]) (2.10)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->pycaret[full]) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect; sys_platform != "win32"->IPython->pycaret[full]) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->IPython->pycaret[full]) (0.8.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow->pycaret[full]) (3.15.0)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /usr/local/lib/python3.8/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow->pycaret[full]) (2.0.2)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.8/dist-packages (from Flask<3->mlflow->pycaret[full]) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.8/dist-packages (from Flask<3->mlflow->pycaret[full]) (2.1.2)
# Collecting pyjwt>=1.7.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from databricks-cli<1,>=0.8.7->mlflow->pycaret[full]) (3.2.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from alembic<2->mlflow->pycaret[full]) (5.12.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 9.6 MB/s eta 0:00:00
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 KB 11.8 MB/s eta 0:00:00
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 KB 52.1 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (6.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->pycaret[full]) (6.3.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels->pyod->pycaret[full]) (0.5.3)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting chart_studio>=1.0.0
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 KB 7.0 MB/s eta 0:00:00
# Collecting flask-compress
#   Downloading Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# Collecting flask-seasurf
#   Downloading Flask_SeaSurf-1.1.1-py3-none-any.whl (8.4 kB)
# Collecting ua_parser
#   Downloading ua_parser-0.16.1-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.8/dist-packages (from dtreeviz>=2.1->explainerdashboard; extra == "full"->pycaret[full]) (3.6.4)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting WTForms>=2.1
#   Downloading WTForms-3.0.1-py3-none-any.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.5/136.5 KB 15.6 MB/s eta 0:00:00
# Collecting Flask-WTF<0.16.0,>=0.15.1
#   Downloading Flask_WTF-0.15.1-py2.py3-none-any.whl (13 kB)
# Collecting antlr4-python3-runtime<4.12,>=4.11.1
#   Downloading antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 KB 16.1 MB/s eta 0:00:00
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 KB 14.4 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting linkify-it-py<3,>=1; extra == "linkify"
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=4.2.0->gradio; extra == "full"->pycaret[full]) (0.12.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio; extra == "full"->pycaret[full]) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio; extra == "full"->pycaret[full]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio; extra == "full"->pycaret[full]) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio; extra == "full"->pycaret[full]) (4.0.2)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 7.3 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.8/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage; extra == "full"->pycaret[full]) (1.5.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage; extra == "full"->pycaret[full]) (1.58.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage; extra == "full"->pycaret[full]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage; extra == "full"->pycaret[full]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage; extra == "full"->pycaret[full]) (5.3.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from pymongo->hyperopt; extra == "full"->pycaret[full]) (2.3.0)
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (0.19.3)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 42.6 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray[tune]>=1.0.0; extra == "full"->pycaret[full]) (3.0.0)
# Collecting lime>=0.1.1.33; extra == "lime"
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 KB 28.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dill>=0.2.5; extra == "shap"
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 13.5 MB/s eta 0:00:00
# Collecting gevent>=1.3.6; extra == "dash"
#   Downloading gevent-22.10.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 70.0 MB/s eta 0:00:00
# Collecting dash-cytoscape>=0.1.1; extra == "dash"
#   Downloading dash_cytoscape-0.3.0-py3-none-any.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 74.6 MB/s eta 0:00:00
# Collecting SALib>=1.3.3; extra == "sensitivity"
#   Downloading salib-1.4.7-py3-none-any.whl (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.0/758.0 KB 57.7 MB/s eta 0:00:00
# Collecting skope-rules>=1.0.1; extra == "skoperules"
#   Downloading skope_rules-1.0.1-py3-none-any.whl (14 kB)
# Collecting treeinterpreter>=0.2.2; extra == "treeinterpreter"
#   Downloading treeinterpreter-0.2.3-py2.py3-none-any.whl (6.0 kB)
# Collecting qtconsole
#   Downloading qtconsole-5.4.0-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.0/121.0 KB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.8/dist-packages (from jupyter->autoviz; extra == "full"->pycaret[full]) (6.5.4)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.8/dist-packages (from jupyter->autoviz; extra == "full"->pycaret[full]) (6.1.0)
# Requirement already satisfied: param>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from panel~=0.12.6->autoviz; extra == "full"->pycaret[full]) (1.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from panel~=0.12.6->autoviz; extra == "full"->pycaret[full]) (6.0.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.8/dist-packages (from panel~=0.12.6->autoviz; extra == "full"->pycaret[full]) (2.2.1)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.8/dist-packages (from panel~=0.12.6->autoviz; extra == "full"->pycaret[full]) (0.5.0)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.8/dist-packages (from holoviews>=1.14.6->autoviz; extra == "full"->pycaret[full]) (3.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=2.1.4->azure-storage-blob; extra == "full"->pycaret[full]) (1.15.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 84.0 MB/s eta 0:00:00
# Collecting imagehash; extra == "type_image_path"
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 KB 30.2 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->pycaret[full]) (5.2.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->pycaret[full]) (23.2.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret[full]) (5.7.3)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret[full]) (21.3.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret[full]) (0.16.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret[full]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret[full]) (0.13.3)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-manylinux1_x86_64.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.2/357.2 KB 35.1 MB/s eta 0:00:00
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest->dtreeviz>=2.1->explainerdashboard; extra == "full"->pycaret[full]) (9.1.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.8/dist-packages (from pytest->dtreeviz>=2.1->explainerdashboard; extra == "full"->pycaret[full]) (1.4.1)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.8/dist-packages (from pytest->dtreeviz>=2.1->explainerdashboard; extra == "full"->pycaret[full]) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from pytest->dtreeviz>=2.1->explainerdashboard; extra == "full"->pycaret[full]) (1.11.0)
# Requirement already satisfied: appdirs~=1.4.3 in /usr/local/lib/python3.8/dist-packages (from fs->triad>=0.8.1->fugue>=0.6.5; extra == "full"->pycaret[full]) (1.4.4)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.8/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3.0dev,>=1.25.0->google-cloud-storage; extra == "full"->pycaret[full]) (0.4.8)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.8/dist-packages (from lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]>=0.2.4->interpret<=0.2.4; extra == "full"->pycaret[full]) (0.19.3)
# Collecting zope.event
#   Downloading zope.event-4.6-py2.py3-none-any.whl (6.8 kB)
# Collecting zope.interface
#   Downloading zope.interface-5.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 KB 23.7 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 15.0 MB/s eta 0:00:00
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 KB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter->autoviz; extra == "full"->pycaret[full]) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter->autoviz; extra == "full"->pycaret[full]) (4.9.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter->autoviz; extra == "full"->pycaret[full]) (0.2.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter->autoviz; extra == "full"->pycaret[full]) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter->autoviz; extra == "full"->pycaret[full]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter->autoviz; extra == "full"->pycaret[full]) (0.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter->autoviz; extra == "full"->pycaret[full]) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter->autoviz; extra == "full"->pycaret[full]) (1.2.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->panel~=0.12.6->autoviz; extra == "full"->pycaret[full]) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob; extra == "full"->pycaret[full]) (2.21)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.8/dist-packages (from imagehash; extra == "type_image_path"->visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling>=2.8.0->pycaret[full]) (1.4.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret[full]) (2.16.3)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.8/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret[full]) (21.2.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.12->lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]>=0.2.4->interpret<=0.2.4; extra == "full"->pycaret[full]) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.12->lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,skoperules,treeinterpreter]>=0.2.4->interpret<=0.2.4; extra == "full"->pycaret[full]) (2023.2.27)
# Building wheels for collected packages: umap-learn, pyod, databricks-cli, pynndescent, dash-auth, fugue-sql-antlr, ffmpy, emoji, htmlmin, lime
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=9c1fbc73a3ced7396b1ed9aaa97bd56708f8832c431fd708a8dbe34d00bcdecf
#   Stored in directory: /root/.cache/pip/wheels/a9/3a/67/06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.0.7-py3-none-any.whl size=181101 sha256=58b9c2fbef5ba89595902d31f55566073d528bc384aa26eb7e8230bde41adc51
#   Stored in directory: /root/.cache/pip/wheels/f7/e2/c1/1c7fd8b261e72411f6509afb429c84532e40ddcd96074473f4
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.4-py3-none-any.whl size=142894 sha256=2cbcc304c07c36e328a797163d9e5be147953d5d60fe57f94c461d5ef9f49170
#   Stored in directory: /root/.cache/pip/wheels/48/7c/6e/4bf2c1748c7ecf994ca951591de81674ed6bf633e1e337d873
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=7bc630deadc00498f9373962b4942fdc65c34531169e8df550e1b4a54dceb973
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
#   Building wheel for dash-auth (setup.py) ... done
#   Created wheel for dash-auth: filename=dash_auth-1.4.1-py3-none-any.whl size=476152 sha256=0d0f853495dda9b324b36b3cfb9303b5f60d257d8bb0f5bc120b431cab1655b1
#   Stored in directory: /root/.cache/pip/wheels/49/39/d4/8b86e01a8b6c9fd63051de54f4ebb256e85d9759505d749c37
#   Building wheel for fugue-sql-antlr (setup.py) ... done
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.1.5-py3-none-any.whl size=157611 sha256=310ff57c1145886ec17ad60dbbaefe9fe54f1c0739308c8993ac680ada2ae2d0
#   Stored in directory: /root/.cache/pip/wheels/20/43/52/82a9d786b53ebc4ba73466f06ae20c3222125a1a5b4b8a0662
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4711 sha256=252899496142387b0fefe9480bc9d78401775f4a85464997458e9e3c04dc42e2
#   Stored in directory: /root/.cache/pip/wheels/ff/5b/59/913b443e7369dc04b61f607a746b6f7d83fb65e2e19fcc958d
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234926 sha256=36a72cf1f1d6208ba7d75ebb3793499305243f2090af6b39d4c2c76c739de8f9
#   Stored in directory: /root/.cache/pip/wheels/86/62/9e/a6b27a681abcde69970dbc0326ff51955f3beac72f15696984
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=bddc77121510579d6486e6a931274e37bb53146762c465177ba257874d38d660
#   Stored in directory: /root/.cache/pip/wheels/23/14/6e/4be5bfeeb027f4939a01764b48edd5996acf574b0913fe5243
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283857 sha256=eb515d633d7e8f394755a88e26e38cac625e05bf7868fc69fd2c7351209a9378
#   Stored in directory: /root/.cache/pip/wheels/e6/a6/20/cc1e293fcdb67ede666fed293cb895395e7ecceb4467779546
# Successfully built umap-learn pyod databricks-cli pynndescent dash-auth fugue-sql-antlr ffmpy emoji htmlmin lime
# Installing collected packages: plac, srsly, catalogue, thinc, spacy, scipy, scikit-learn, kmodes, mlxtend, gunicorn, slicer, llvmlite, numba, shap, pyyaml, websocket-client, docker, querystring-parser, pyjwt, databricks-cli, smmap, gitdb, gitpython, Mako, alembic, mlflow, htmlmin, multimethod, typeguard, tangled-up-in-unicode, imagehash, visions, phik, ydata-profiling, pandas-profiling, imbalanced-learn, scikit-plot, lightgbm, pynndescent, umap-learn, Boruta, funcy, pyLDAvis, pyod, evidently, graphviz, dash-table, dash-core-components, dash-html-components, dash, ansi2html, nest-asyncio, retrying, jupyter-dash, dash-bootstrap-components, chart_studio, brotli, flask-compress, flask-seasurf, ua_parser, dash-auth, colour, dtreeviz, WTForms, Flask-WTF, flask-simplelogin, waitress, oyaml, explainerdashboard, antlr4-python3-runtime, fs, triad, adagio, qpd, sqlglot, fugue-sql-antlr, fugue, jmespath, botocore, s3transfer, boto3, mdurl, uc-micro-py, linkify-it-py, markdown-it-py, orjson, pydub, mdit-py-plugins, python-multipart, h11, uvicorn, ffmpy, sniffio, anyio, starlette, fastapi, httpcore, rfc3986, httpx, pycryptodome, aiofiles, websockets, gradio, pyaml, scikit-optimize, fairlearn, catboost, distlib, virtualenv, tensorboardX, ray, tune-sklearn, cmaes, colorlog, optuna, lime, dill, zope.event, zope.interface, gevent, dash-cytoscape, multiprocess, SALib, skope-rules, treeinterpreter, interpret-core, interpret, qtpy, qtconsole, jupyter, panel, pyamg, hvplot, emoji, autoviz, m2cgen, cryptography, azure-core, isodate, azure-storage-blob, pycaret, jedi
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.6
#     Uninstalling srsly-2.4.6:
#       Successfully uninstalled srsly-2.4.6
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.7
#     Uninstalling thinc-8.1.7:
#       Successfully uninstalled thinc-8.1.7
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.1
#     Uninstalling scikit-learn-1.2.1:
#       Successfully uninstalled scikit-learn-1.2.1
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.4
#     Uninstalling numba-0.56.4:
#       Successfully uninstalled numba-0.56.4
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 2.7.1
#     Uninstalling typeguard-2.7.1:
#       Successfully uninstalled typeguard-2.7.1
#   Attempting uninstall: pandas-profiling
#     Found existing installation: pandas-profiling 1.4.1
#     Uninstalling pandas-profiling-1.4.1:
#       Successfully uninstalled pandas-profiling-1.4.1
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.8.1
#     Uninstalling imbalanced-learn-0.8.1:
#       Successfully uninstalled imbalanced-learn-0.8.1
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
#   Attempting uninstall: panel
#     Found existing installation: panel 0.14.3
#     Uninstalling panel-0.14.3:
#       Successfully uninstalled panel-0.14.3
# ERROR: pip's legacy dependency resolver does not consider dependency conflicts when selecting packages. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you'll have scikit-learn 0.23.2 which is incompatible.
# xarray-einstats 0.5.1 requires scipy>=1.6, but you'll have scipy 1.5.4 which is incompatible.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you'll have numpy 1.22.4 which is incompatible.
# mlxtend 0.21.0 requires scikit-learn>=1.0.2, but you'll have scikit-learn 0.23.2 which is incompatible.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you'll have spacy 2.3.9 which is incompatible.
# confection 0.0.4 requires srsly<3.0.0,>=2.4.0, but you'll have srsly 1.0.6 which is incompatible.
# docker 6.0.1 requires requests>=2.26.0, but you'll have requests 2.25.1 which is incompatible.
# pyldavis 3.4.0 requires scikit-learn>=1.0.0, but you'll have scikit-learn 0.23.2 which is incompatible.
# evidently 0.2.6 requires scikit-learn>=0.24.0, but you'll have scikit-learn 0.23.2 which is incompatible.
# explainerdashboard 0.4.2.1 requires scikit-learn>=1.1, but you'll have scikit-learn 0.23.2 which is incompatible.
# salib 1.4.7 requires scipy>=1.7.3, but you'll have scipy 1.5.4 which is incompatible.
# Successfully installed Boruta-0.3 Flask-WTF-0.15.1 Mako-1.2.4 SALib-1.4.7 WTForms-3.0.1 adagio-0.2.4 aiofiles-23.1.0 alembic-1.10.1 ansi2html-1.8.0 antlr4-python3-runtime-4.11.1 anyio-3.6.2 autoviz-0.1.58 azure-core-1.26.3 azure-storage-blob-12.15.0 boto3-1.26.85 botocore-1.29.85 brotli-1.0.9 catalogue-1.0.2 catboost-1.1.1 chart_studio-1.1.0 cmaes-0.9.1 colorlog-6.7.0 colour-0.1.5 cryptography-39.0.2 dash-2.8.1 dash-auth-1.4.1 dash-bootstrap-components-1.4.0 dash-core-components-2.0.0 dash-cytoscape-0.3.0 dash-html-components-2.0.0 dash-table-5.0.0 databricks-cli-0.17.4 dill-0.3.6 distlib-0.3.6 docker-6.0.1 dtreeviz-2.2.0 emoji-2.2.0 evidently-0.2.6 explainerdashboard-0.4.2.1 fairlearn-0.8.0 fastapi-0.92.0 ffmpy-0.3.0 flask-compress-1.13 flask-seasurf-1.1.1 flask-simplelogin-0.1.1 fs-2.4.16 fugue-0.8.1 fugue-sql-antlr-0.1.5 funcy-1.18 gevent-22.10.2 gitdb-4.0.10 gitpython-3.1.31 gradio-3.20.1 graphviz-0.20.1 gunicorn-20.1.0 h11-0.14.0 htmlmin-0.1.12 httpcore-0.16.3 httpx-0.23.3 hvplot-0.8.2 imagehash-4.3.1 imbalanced-learn-0.7.0 interpret-0.2.4 interpret-core-0.3.0 isodate-0.6.1 jedi-0.18.2 jmespath-1.0.1 jupyter-1.0.0 jupyter-dash-0.4.2 kmodes-0.12.2 lightgbm-3.3.5 lime-0.2.0.1 linkify-it-py-2.0.0 llvmlite-0.37.0 m2cgen-0.10.0 markdown-it-py-2.2.0 mdit-py-plugins-0.3.3 mdurl-0.1.2 mlflow-2.2.1 mlxtend-0.21.0 multimethod-1.9.1 multiprocess-0.70.14 nest-asyncio-1.5.6 numba-0.54.1 optuna-3.1.0 orjson-3.8.7 oyaml-1.0 pandas-profiling-3.6.6 panel-0.12.7 phik-0.12.3 plac-1.1.3 pyLDAvis-3.4.0 pyamg-4.2.3 pyaml-21.10.1 pycaret-2.3.10 pycryptodome-3.17 pydub-0.25.1 pyjwt-2.6.0 pynndescent-0.5.8 pyod-1.0.7 python-multipart-0.0.6 pyyaml-5.4.1 qpd-0.4.0 qtconsole-5.4.0 qtpy-2.3.0 querystring-parser-1.2.4 ray-2.3.0 retrying-1.3.4 rfc3986-1.5.0 s3transfer-0.6.0 scikit-learn-0.23.2 scikit-optimize-0.9.0 scikit-plot-0.3.7 scipy-1.5.4 shap-0.41.0 skope-rules-1.0.1 slicer-0.0.7 smmap-5.0.0 sniffio-1.3.0 spacy-2.3.9 sqlglot-11.3.0 srsly-1.0.6 starlette-0.25.0 tangled-up-in-unicode-0.2.0 tensorboardX-2.6 thinc-7.4.6 treeinterpreter-0.2.3 triad-0.8.2 tune-sklearn-0.4.5 typeguard-2.13.3 ua_parser-0.16.1 uc-micro-py-1.0.1 umap-learn-0.5.3 uvicorn-0.20.0 virtualenv-20.20.0 visions-0.7.5 waitress-2.1.2 websocket-client-1.5.1 websockets-10.4 ydata-profiling-4.0.0 zope.event-4.6 zope.interface-5.5.2

# %%
# !pip install numba==0.53
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numba==0.53
#   Downloading numba-0.53.0-cp38-cp38-manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 30.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.8/dist-packages (from numba==0.53) (1.22.4)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp38-cp38-manylinux2010_x86_64.whl (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 61.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba==0.53) (57.4.0)
# Installing collected packages: llvmlite, numba
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.37.0
#     Uninstalling llvmlite-0.37.0:
#       Successfully uninstalled llvmlite-0.37.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.54.1
#     Uninstalling numba-0.54.1:
#       Successfully uninstalled numba-0.54.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# explainerdashboard 0.4.2.1 requires scikit-learn>=1.1, but you have scikit-learn 0.23.2 which is incompatible.
# Successfully installed llvmlite-0.36.0 numba-0.53.0

# %%
# !pip uninstall sklearn -y
# !pip install --upgrade sklearn
# !pip install scikit-learn==0.2 --user
# Out:
# WARNING: Skipping sklearn as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=2e501fcb584b453ccc382b65a34dd9bb5e0f8415c657f22dffe4ea12205e529f
#   Stored in directory: /root/.cache/pip/wheels/14/25/f7/1cc0956978ae479e75140219088deb7a36f60459df242b1a72
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement scikit-learn==0.2 (from versions: 0.9, 0.10, 0.11, 0.12, 0.12.1, 0.13, 0.13.1, 0.14, 0.14.1, 0.15.0, 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.17, 0.17.1, 0.18, 0.18.1, 0.18.2, 0.19.0, 0.19.1, 0.19.2, 0.20.0, 0.20.1, 0.20.2, 0.20.3, 0.20.4, 0.21.1, 0.21.2, 0.21.3, 0.22, 0.22.1, 0.22.2, 0.22.2.post1, 0.23.0, 0.23.1, 0.23.2, 0.24.0, 0.24.1, 0.24.2, 1.0, 1.0.1, 1.0.2, 1.1.0, 1.1.1, 1.1.2, 1.1.3, 1.2.0rc1, 1.2.0, 1.2.1)
# ERROR: No matching distribution found for scikit-learn==0.2

# %% [markdown]
# #### Setup

# %%
train_df = pd.concat([df[df['Season'] >= 2013][features], df[df['Season'] >= 2013]['WinA']],axis=1)

test_df = df_test[features]

# %%
#Lucky이 상관계수는 낮은데 막상 모델에서 중요도가 좋게 나올때가 존재했음

train_df.corr()['WinA'].sort_values()
# Out:
# SeedDiff              -0.52
# AdjDDiff              -0.24
# TOmarginDiff          -0.14
# LuckyDiff             -0.01
# FTDiff                 0.09
# FG3Diff                0.18
# FGDiff                 0.33
# WinRatioDiff           0.33
# AdjODiff               0.37
# TourneyY_3yearsDiff    0.39
# WinRatio_3yearsDiff    0.39
# AdjEMDiff              0.41
# GapAvgDiff             0.42
# GapAvg_3yearsDiff      0.43
# WinA                   1.00
# Name: WinA, dtype: float64

# %%
train_df[(train_df['SeedDiff'] > 6) * (train_df['WinA'] ==1)]
# Out:
#       SeedDiff  WinRatioDiff  GapAvgDiff  FGDiff  FG3Diff  FTDiff  \
# 761          7         -0.24       -9.55    0.04     0.01   -0.00
# 791          8         -0.21       -9.43    0.04     0.06    0.14
# 821          7          0.03       -1.09   -0.01     0.01   -0.01
# 852          8          0.01       -4.02   -0.01    -0.01   -0.06
# 917          8         -0.09       -5.05   -0.02    -0.02    0.07
# ...        ...           ...         ...     ...      ...     ...
# 2676         7         -0.09       -7.09   -0.01     0.02    0.07
# 2678         8         -0.31      -10.07   -0.04     0.01   -0.01
# 2683         8         -0.15       -0.69    0.01     0.01   -0.10
# 2684         8         -0.15       -7.90    0.04     0.02    0.03
# 2695        12         -0.17       -7.10   -0.07    -0.04   -0.01
#
#       TOmarginDiff  WinRatio_3yearsDiff  GapAvg_3yearsDiff  AdjODiff  \
# 761           3.23                -0.02               0.46      0.00
# 791           3.77                -0.08              -2.55     -0.00
# 821           3.64                 0.16               3.60     -0.05
# 852           4.25                -0.00              -1.08     -0.04
# 917          -2.36                 0.22               8.89     -0.02
# ...            ...                  ...                ...       ...
# 2676          4.70                -0.26             -10.39     -0.02
# 2678          2.69                -0.12              -7.01     -0.10
# 2683          0.11                -0.29              -6.95     -0.04
# 2684         -1.38                -0.19              -7.44      0.00
# 2695         -2.31                -0.07              -4.94     -0.13
#
#       AdjDDiff  AdjEMDiff  LuckyDiff  TourneyY_3yearsDiff  WinA
# 761       0.10      -0.10      -0.02                 1.00     1
# 791       0.11      -0.11       0.02                 0.00     1
# 821      -0.05      -0.00       0.03                 0.00     1
# 852      -0.00      -0.04       0.05                -2.00     1
# 917       0.03      -0.05      -0.00                 3.00     1
# ...        ...        ...        ...                  ...   ...
# 2676      0.05      -0.07       0.00                 1.00     1
# 2678      0.00      -0.10      -0.12                -2.00     1
# 2683     -0.04      -0.00      -0.11                -1.00     1
# 2684      0.08      -0.08       0.02                -1.00     1
# 2695     -0.06      -0.07      -0.06                -3.00     1
#
# [83 rows x 15 columns]

# %% [markdown]
# 오류 생기면 런타임 재시작

# %%
#https://pycaret.readthedocs.io/en/latest/api/regression.html

from pycaret.classification import *

pd.options.display.float_format = None

clf_test_1 = setup(data=train_df,   # df 설정
                   target='WinA', # Target 설정
                   train_size= 0.7, # size 설정
                   fold=10,
                   normalize = True,
                   transformation = False,
                   #pca = True,
                   #pca_components = 0.8,
                   feature_selection = False,
                   session_id = 4629,
                   silent=True,
                   #remove_outliers = True,
                   use_gpu = True,
                   #ordinal_features = {'key' : [i for i in range(12)]}'# Fold 설정
                   )
# Out:
#                                Description             Value
# 0                               session_id              4629
# 1                                   Target              WinA
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data        (2346, 15)
# 5                           Missing Values             False
# 6                         Numeric Features                14
# 7                     Categorical Features                 0
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set        (1642, 13)
# 12                    Transformed Test Set         (704, 13)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU              True
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              38a5
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize              True
# 30                        Normalize Method            zscore
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE
# INFO:logs:create_model_container: 0
# INFO:logs:master_model_container: 0
# INFO:logs:display_container: 1
# INFO:logs:Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                   target='WinA')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='WinA')),
#                 ('fix_perfect', Remove_100(target='WinA')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# INFO:logs:setup() succesfully completed......................................

# %%
#logloss 적용 및 predict_proba로 제출하기 위해 metric 추가
add_metric('logloss', 'LogLoss', log_loss, greater_is_better=False, target="pred_proba")

from sklearn.metrics import brier_score_loss

add_metric('Brier', 'Brier', brier_score_loss, greater_is_better=False, target="pred_proba")
# Out:
# Name                                                             Brier
# Display Name                                                     Brier
# Score Function           <function brier_score_loss at 0x7f4bdaa640d0>
# Scorer               make_scorer(brier_score_loss, greater_is_bette...
# Target                                                      pred_proba
# Args                                                                {}
# Greater is Better                                                False
# Multiclass                                                        True
# Custom                                                            True
# Name: Brier, dtype: object

# %%
# define Cauchy loss function for classification problems
def cauchy_loss_classification(y_true, y_pred):
    c = 2.0

    residual = (y_true - y_pred)
    
    loss = c**2 * np.log(1 + (residual**2) / c **2) /2
    
    return float(loss)

add_metric(id="my_metric", name="My Metric", score_func=cauchy_loss_classification, target="pred_proba", greater_is_better=False)
# Out:
# Name                                                         My Metric
# Display Name                                                 My Metric
# Score Function       <function cauchy_loss_classification at 0x7f4b...
# Scorer               make_scorer(cauchy_loss_classification, greate...
# Target                                                      pred_proba
# Args                                                                {}
# Greater is Better                                                False
# Multiclass                                                        True
# Custom                                                            True
# Name: my_metric, dtype: object

# %% [markdown]
# ### Blended Model

# %%
#Brier score가 높은 모델 3개를 앙상블 (제외된 2개의 모델은 Brier score를 구할 수 없어서 제외함)

custom_model = compare_models(fold = 10, 
                              sort = 'Brier', 
                              n_select = 3, 
                              exclude=['svm','ridge'])
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7254  0.8083  0.7225  0.7222
# lda          Linear Discriminant Analysis    0.7260  0.8077  0.7164  0.7260
# et                 Extra Trees Classifier    0.7126  0.7929  0.6806  0.7243
# catboost              CatBoost Classifier    0.7186  0.7950  0.6978  0.7231
# rf               Random Forest Classifier    0.7041  0.7912  0.6658  0.7174
# gbc          Gradient Boosting Classifier    0.7022  0.7928  0.6794  0.7070
# lightgbm  Light Gradient Boosting Machine    0.7028  0.7836  0.6880  0.7056
# knn                K Neighbors Classifier    0.6827  0.7369  0.6745  0.6809
# qda       Quadratic Discriminant Analysis    0.6736  0.7641  0.7125  0.6787
# xgboost         Extreme Gradient Boosting    0.6919  0.7708  0.6757  0.6940
# ada                  Ada Boost Classifier    0.6894  0.7747  0.6744  0.6922
# dummy                    Dummy Classifier    0.5061  0.5000  0.0000  0.0000
# nb                            Naive Bayes    0.6918  0.7715  0.6843  0.6906
# dt               Decision Tree Classifier    0.6510  0.6509  0.6411  0.6496
#
#               F1   Kappa     MCC  LogLoss   Brier  My Metric  TT (Sec)
# lr        0.7219  0.4506  0.4512   0.5264  0.1791        0.0     0.036
# lda       0.7207  0.4518  0.4524   0.5275  0.1792        0.0     0.018
# et        0.7007  0.4247  0.4266   0.5422  0.1854        0.0     0.697
# catboost  0.7099  0.4370  0.4376   0.5460  0.1858        0.0     2.415
# rf        0.6896  0.4076  0.4097   0.5470  0.1864        0.0     0.753
# gbc       0.6924  0.4040  0.4049   0.5483  0.1870        0.0     0.560
# lightgbm  0.6958  0.4054  0.4065   0.6191  0.2022        0.0     0.261
# knn       0.6769  0.3653  0.3660   1.6905  0.2149        0.0     0.044
# qda       0.6727  0.3479  0.3704   0.6615  0.2206        0.0     0.023
# xgboost   0.6844  0.3834  0.3839   0.7225  0.2225        0.0     0.428
# ada       0.6812  0.3785  0.3805   0.6541  0.2319        0.0     0.306
# dummy     0.0000  0.0000  0.0000   0.6931  0.2500        0.0     0.011
# nb        0.6864  0.3835  0.3845   1.0705  0.2519        0.0     0.015
# dt        0.6446  0.3019  0.3025  12.0537  0.3490        0.0     0.029
# INFO:logs:create_model_container: 14
# INFO:logs:master_model_container: 14
# INFO:logs:display_container: 2
# INFO:logs:[LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=4629, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001), ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=4629, verbose=0,
#                      warm_start=False)]
# INFO:logs:compare_models() succesfully completed......................................

# %%
# # 가장 좋은 모델에 대해 튜닝

# tuned_top = [tune_model(i, optimize = 'my_metric') for i in custom_model]

# %%
# 가장 좋은 모델에 대해 튜닝

tuned_top = [tune_model(i, optimize = 'Brier') for i in custom_model]
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC  LogLoss  \
# Fold
# 0       0.6788  0.7638  0.6914  0.6667  0.6788  0.3578  0.3580   0.5656
# 1       0.7333  0.8213  0.7317  0.7317  0.7317  0.4666  0.4666   0.5205
# 2       0.7256  0.8105  0.6914  0.7368  0.7134  0.4507  0.4516   0.5310
# 3       0.7256  0.7785  0.7037  0.7308  0.7170  0.4509  0.4512   0.5642
# 4       0.7683  0.8501  0.7407  0.7792  0.7595  0.5362  0.5369   0.4932
# 5       0.7195  0.7946  0.6173  0.7692  0.6849  0.4376  0.4462   0.5326
# 6       0.6646  0.7461  0.7160  0.6444  0.6784  0.3301  0.3321   0.5898
# 7       0.7500  0.8292  0.6790  0.7857  0.7285  0.4991  0.5037   0.5159
# 8       0.7439  0.8328  0.7284  0.7468  0.7375  0.4876  0.4877   0.5066
# 9       0.7256  0.8105  0.6790  0.7432  0.7097  0.4506  0.4522   0.5290
# Mean    0.7235  0.8037  0.6979  0.7335  0.7139  0.4467  0.4486   0.5348
# Std     0.0295  0.0311  0.0340  0.0433  0.0255  0.0587  0.0587   0.0282
#
#        Brier  My Metric
# Fold
# 0     0.1958       -0.0
# 1     0.1744       -0.0
# 2     0.1789       -0.0
# 3     0.1928       -0.0
# 4     0.1625       -0.0
# 5     0.1803       -0.0
# 6     0.2036       -0.0
# 7     0.1729       -0.0
# 8     0.1689       -0.0
# 9     0.1786       -0.0
# Mean  0.1809        0.0
# Std   0.0121        0.0
# INFO:logs:create_model_container: 17
# INFO:logs:master_model_container: 17
# INFO:logs:display_container: 5
# INFO:logs:ExtraTreesClassifier(bootstrap=True, ccp_alpha=0.0, class_weight={},
#                      criterion='gini', max_depth=4, max_features=1.0,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.001, min_impurity_split=None,
#                      min_samples_leaf=6, min_samples_split=10,
#                      min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#                      oob_score=False, random_state=4629, verbose=0,
#                      warm_start=False)
# INFO:logs:tune_model() succesfully completed......................................

# %%
# Brier score

blended_custom = blend_models(estimator_list = tuned_top,
                              fold = 10,
                              optimize = 'Brier')

pred_holdout_custom = predict_model(blended_custom)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC  LogLoss  \
# Fold
# 0       0.6970  0.7695  0.7160  0.6824  0.6988  0.3943  0.3947   0.5641
# 1       0.7333  0.8221  0.7439  0.7262  0.7349  0.4667  0.4669   0.5105
# 2       0.7195  0.8175  0.7037  0.7215  0.7125  0.4388  0.4389   0.5173
# 3       0.7256  0.7907  0.7037  0.7308  0.7170  0.4509  0.4512   0.5509
# 4       0.7744  0.8530  0.7901  0.7619  0.7758  0.5489  0.5493   0.4781
# 5       0.7195  0.7921  0.6667  0.7397  0.7013  0.4383  0.4404   0.5422
# 6       0.6951  0.7633  0.7284  0.6782  0.7024  0.3907  0.3917   0.5800
# 7       0.7195  0.8234  0.6914  0.7273  0.7089  0.4386  0.4391   0.5134
# 8       0.7317  0.8498  0.7160  0.7342  0.7250  0.4632  0.4633   0.4891
# 9       0.7134  0.8123  0.6790  0.7237  0.7006  0.4263  0.4271   0.5194
# Mean    0.7229  0.8094  0.7139  0.7226  0.7177  0.4457  0.4463   0.5265
# Std     0.0210  0.0289  0.0333  0.0238  0.0223  0.0420  0.0418   0.0307
#
#        Brier  My Metric
# Fold
# 0     0.1957       -0.0
# 1     0.1712       -0.0
# 2     0.1746       -0.0
# 3     0.1870       -0.0
# 4     0.1584       -0.0
# 5     0.1853       -0.0
# 6     0.1993       -0.0
# 7     0.1732       -0.0
# 8     0.1631       -0.0
# 9     0.1759       -0.0
# Mean  0.1784        0.0
# Std   0.0126        0.0
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 6
# INFO:logs:VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=1, verbose=False, voting='soft',
#                  weights=None)
# INFO:logs:blend_models() succesfully completed......................................
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=1, verbose=False, voting='soft',
#                  weights=None), probability_threshold=None, encoded_labels=False, drift_report=False, raw_score=False, round=4, verbose=True, ml_usecase=MLUsecase.CLASSIFICATION, display=None, drift_kwargs=None)
# INFO:logs:Checking exceptions
# INFO:logs:Preloading libraries
# INFO:logs:Preparing display monitor
#                Model  Accuracy     AUC  Recall   Prec.      F1  Kappa     MCC  \
# 0  Voting Classifier    0.7585  0.8365  0.7541  0.7712  0.7626  0.517  0.5171
#
#    LogLoss   Brier  My Metric
# 0   0.5015  0.1659          0

# %%
#최종 모델
final_model_custom = finalize_model(blended_custom)
# Out:
# INFO:logs:Initializing finalize_model()
# INFO:logs:finalize_model(estimator=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=1, verbose=False, voting='soft',
#                  weights=None), fit_kwargs=None, groups=None, model_only=True, display=None, experiment_custom_tags=None, return_train_score=False)
# INFO:logs:Finalizing VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=1, verbose=False, voting='soft',
#                  weights=None)
# INFO:logs:Initializing create_model()
# INFO:logs:create_model(estimator=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=1, verbose=False, voting='soft',
#                  weights=None), fold=None, round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=True, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=False, probability_threshold=None, display=None, return_train_score=False, kwargs={})
# INFO:logs:Checking exceptions
# INFO:logs:Importing libraries
# INFO:logs:Copying training dataset
# INFO:logs:Defining folds
# INFO:logs:Declaring metric variables
# INFO:logs:Importing untrained model
# INFO:logs:Declaring custom model
# INFO:logs:Voting Classifier Imported succesfully
# INFO:logs:Starting cross validation
# INFO:logs:Cross validating with StratifiedKFold(n_splits=10, random_state=None, shuffle=False), n_jobs=1
# INFO:logs:Calculating mean and std
# INFO:logs:Creating metrics dataframe
# INFO:logs:Finalizing model
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 8
# INFO:logs:VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=1, verbose=False, voting='soft',
#                  weights=None)
# INFO:logs:create_model() succesfully completed......................................
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 7
# INFO:logs:VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=1, verbose=False, voting='soft',
#                  weights=None)
# INFO:logs:finalize_model() succesfully completed......................................

# %%
#X has 6 features per sample; expecting 30 오류 생길 시 setup 부터 다시

import datetime

now = datetime.datetime.now()

save_model(final_model_custom, f"/content/Model_test_{datetime.datetime.now()}")

prep_pipe = get_config("prep_pipe")

prep_pipe.steps.append(['trained_model', final_model_custom])

predictions = predict_model(prep_pipe,
                            data=test_df,
                            raw_score=True)
# Out:
# INFO:logs:Initializing save_model()
# INFO:logs:save_model(model=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=1, verbose=False, voting='soft',
#                  weights=None), model_name=/content/Model_test_2023-03-07 09:36:26.281595, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                   target='WinA')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='WinA')),
#                 ('fix_perfect', Remove_100(target='WinA')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False), verbose=True, kwargs={})
# INFO:logs:Adding model into prep_pipe
# INFO:logs:/content/Model_test_2023-03-07 09:36:26.281595.pkl saved in current working directory
# INFO:logs:Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                                     max_features=1.0,
#                                                                     max_leaf_nodes=None,
#                                                                     max_samples=None,
#                                                                     min_impurity_decrease=0.001,
#                                                                     min_impurity_split=None,
#                                                                     min_samples_leaf=6,
#                                                                     min_samples_split=10,
#                                                                     min_weight_fraction_leaf=0.0,
#                                                                     n_estimators=200,
#                                                                     n_jobs=-1,
#                                                                     oob_score=False,
#                                                                     random_state=4629,
#                                                                     verbose=0,
#                                                                     warm_start=False))],
#                                   flatten_transform=True, n_jobs=1,
#                                   verbose=False, voting='soft',
#                                   weights=None)]],
#          verbose=False)
# INFO:logs:save_model() successfully completed......................................
# Transformation Pipeline and Model Successfully Saved
# INFO:logs:Initializing get_config()
# INFO:logs:get_config(variable=prep_pipe)
# INFO:logs:Global variable: prep_pipe returned as Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                   target='WinA')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='WinA')),
#                 ('fix_perfect', Remove_100(target='WinA')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# INFO:logs:get_config() succesfully completed......................................
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                                     max_features=1.0,
#                                                                     max_leaf_nodes=None,
#                                                                     max_samples=None,
#                                                                     min_impurity_decrease=0.001,
#                                                                     min_impurity_split=None,
#                                                                     min_samples_leaf=6,
#                                                                     min_samples_split=10,
#                                                                     min_weight_fraction_leaf=0.0,
#                                                                     n_estimators=200,
#                                                                     n_jobs=-1,
#                                                                     oob_score=False,
#                                                                     random_state=4629,
#                                                                     verbose=0,
#                                                                     warm_start=False))],
#                                   flatten_transform=True, n_jobs=1,
#                                   verbose=False, voting='soft',
#                                   weights=None)]],
#          verbose=False), probability_threshold=None, encoded_labels=False, drift_report=False, raw_score=True, round=4, verbose=True, ml_usecase=MLUsecase.CLASSIFICATION, display=None, drift_kwargs=None)
# INFO:logs:Checking exceptions
# INFO:logs:Preloading libraries
# INFO:logs:Preparing display monitor

# %%
df_test_after_AutoML = df_test.copy()

df_test_after_AutoML['pred'] = predictions['Score_1']

_ = sns.displot(predictions['Score_1'])

# %% [markdown]
# #### 최종 제출 파일

# %%
final_sub_after_AutoML = df_test_after_AutoML[['ID', 'pred']].copy()

final_sub_after_AutoML.to_csv('submission_total_0305.csv', index=False)

# %%
final_sub_after_AutoML
# Out:
#                     ID    pred
# 0       2023_1101_1102  0.6196
# 1       2023_1101_1103  0.5669
# 2       2023_1101_1104  0.5433
# 3       2023_1101_1105  0.6073
# 4       2023_1101_1106  0.6818
# ...                ...     ...
# 130678  2023_3474_3476  0.4175
# 130679  2023_3474_3477  0.4135
# 130680  2023_3475_3476  0.5639
# 130681  2023_3475_3477  0.5536
# 130682  2023_3476_3477  0.4918
#
# [130683 rows x 2 columns]

# %%
final_sub_after_AutoML[final_sub_after_AutoML['pred'] < 0.5]
# Out:
#                     ID    pred
# 13      2023_1101_1116  0.4476
# 19      2023_1101_1124  0.4893
# 51      2023_1101_1159  0.4555
# 53      2023_1101_1161  0.4765
# 55      2023_1101_1163  0.4594
# ...                ...     ...
# 130676  2023_3473_3477  0.3875
# 130677  2023_3474_3475  0.3633
# 130678  2023_3474_3476  0.4175
# 130679  2023_3474_3477  0.4135
# 130682  2023_3476_3477  0.4918
#
# [64542 rows x 2 columns]

# %%
# #모델 불러오기

# load_model = load_model("/content/Model_test_2023-03-05")

# predictions = predict_model(load_model,
#                             data=test_df)

# %% [markdown]
# ### Test : 각년도별로 test

# %%
for year in df['Season'].unique():

  df_val = df[df['Season'] == year]

  df_val = df_val.reset_index(drop=True)

  prediction = prep_pipe.predict_proba(df_val[features])

  i, j = [], []
  for row in prediction:
    i.append(row[0])
    j.append(row[1])

  len(i), len(j)

  df_val['pred'] = j

  df_val['WinA_pred'] = prep_pipe.predict(df_val[features])
  
  #plt.figure(figsize=(12, 6))
  fig, ax = plt.subplots(1, 2,figsize = [12, 6])
  ax[0].set_ylim(-60, 60)
  ax[0].scatter(df_val['pred'], df_val['ScoreDiff'].values, s=10)
  ax[0].set_title('Prediction vs Score Diff')

  ax[1].hist(df_val['pred'], bins = 10, alpha = 0.4)
  ax[1].set_title('Predictions probability repartition')

  fig.suptitle(f'{year} Result', fontsize=16) # figure 제목

  fig.tight_layout() # 사용하면 플롯간 여백을 조정해준다. 
  plt.show()
  
  print(f'{year} Score : ', brier_score_loss(df_val['WinA'], df_val['pred']))
# Out:
# 2001 Score :  0.18000344477695668
# 2002 Score :  0.17645642991956403
# 2003 Score :  0.15855406107794215
# 2004 Score :  0.16744992995154537
# 2005 Score :  0.17238856081342774
# 2006 Score :  0.17662991310923323
# 2007 Score :  0.1557971752402696
# 2008 Score :  0.1496135456052497
# 2009 Score :  0.1677709208508198
# 2010 Score :  0.17009281789759645
# 2011 Score :  0.16884125750797738
# 2012 Score :  0.16610127860376409
# 2013 Score :  0.18225583412249358
# 2014 Score :  0.17888012310429907
# 2015 Score :  0.13995451874396134
# 2016 Score :  0.1720459745654994
# 2017 Score :  0.16085160159546716
# 2018 Score :  0.1865485314405316
# 2019 Score :  0.15221991827147166
# 2021 Score :  0.18424177114891685
# 2022 Score :  0.1901737990793368

# %%
plot_model(final_model_custom, plot = 'learning', use_train_data = True)
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() succesfully completed......................................

# %% [markdown]
# # Woman / Man 분화

# %%
train_man = df[df['Season'] >= 2003][df[df['Season'] >= 2003]['TeamIdA'].astype('str').str.contains('^1',regex= True)]

train_woman = df[df['Season'] >= 2016][df[df['Season'] >= 2016]['TeamIdA'].astype('str').str.contains('^3',regex= True)]

test_man = df_test[df_test['TeamIdA'].astype('str').str.contains('^1',regex= True)]

test_woman = df_test[df_test['TeamIdA'].astype('str').str.contains('^3',regex= True)]

# %%
train_df_man = pd.concat([train_man[features], train_man['WinA']],axis=1)

test_df_man = test_man[features]

# %%
train_df_man.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2240 entries, 1583 to 2702
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SeedDiff             2240 non-null   int64
#  1   WinRatioDiff         2240 non-null   float64
#  2   GapAvgDiff           2240 non-null   float64
#  3   FGDiff               2240 non-null   float64
#  4   FG3Diff              2240 non-null   float64
#  5   FTDiff               2240 non-null   float64
#  6   TOmarginDiff         2240 non-null   float64
#  7   WinRatio_3yearsDiff  2240 non-null   float64
#  8   GapAvg_3yearsDiff    2240 non-null   float64
#  9   AdjODiff             2240 non-null   float64
#  10  AdjDDiff             2240 non-null   float64
#  11  AdjEMDiff            2240 non-null   float64
#  12  LuckyDiff            2240 non-null   float64
#  13  TourneyY_3yearsDiff  2240 non-null   float64
#  14  WinA                 2240 non-null   int64
# dtypes: float64(13), int64(2)
# memory usage: 280.0 KB

# %%
train_df_woman = pd.concat([train_woman[features], train_woman['WinA']],axis=1)

test_df_woman = test_woman[features]

# %% [markdown]
# ## Man

# %%
from pycaret.classification import *

pd.options.display.float_format = None

clf_test_2 = setup(data=train_df_man,   # df 설정
                   target='WinA', # Target 설정
                   train_size= 0.7, # size 설정
                   fold=10,
                   normalize = True,
                   transformation = False,
                   pca = False,
                   feature_selection = False,
                   session_id = 4629,
                   silent=True,
                   #remove_outliers = True,
                   #use_gpu = True,
                   #ordinal_features = {'key' : [i for i in range(12)]}'# Fold 설정
                   )

#logloss 적용 및 predict_proba로 제출하기 위해 metric 추가
add_metric('logloss', 'LogLoss', log_loss, greater_is_better=False, target="pred_proba")

from sklearn.metrics import brier_score_loss

add_metric('Brier', 'Brier', brier_score_loss, greater_is_better=False, target="pred_proba")
# Out:
#                                Description             Value
# 0                               session_id              4629
# 1                                   Target              WinA
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data        (2240, 15)
# 5                           Missing Values             False
# 6                         Numeric Features                14
# 7                     Categorical Features                 0
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set        (1567, 14)
# 12                    Transformed Test Set         (673, 14)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              b693
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize              True
# 30                        Normalize Method            zscore
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE
# INFO:logs:create_model_container: 0
# INFO:logs:master_model_container: 0
# INFO:logs:display_container: 1
# INFO:logs:Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                   target='WinA')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='WinA')),
#                 ('fix_perfect', Remove_100(target='WinA')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# INFO:logs:setup() succesfully completed......................................
# Name                                                             Brier
# Display Name                                                     Brier
# Score Function           <function brier_score_loss at 0x7f4bdaa640d0>
# Scorer               make_scorer(brier_score_loss, greater_is_bette...
# Target                                                      pred_proba
# Args                                                                {}
# Greater is Better                                                False
# Multiclass                                                        True
# Custom                                                            True
# Name: Brier, dtype: object

# %%
#Brier score가 높은 모델 3개를 앙상블 (제외된 2개의 모델은 Brier score를 구할 수 없어서 제외함)
#Brier score가 지나치게 높게 나오는데 CV에 따른 차이로 생각됨.

custom_model = compare_models(fold = 10, 
                              sort = 'Brier', 
                              n_select = 3, 
                              exclude=['svm','ridge'])
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.6937  0.7795  0.7000  0.6951
# lda          Linear Discriminant Analysis    0.6956  0.7798  0.7013  0.6973
# gbc          Gradient Boosting Classifier    0.6809  0.7598  0.7025  0.6781
# catboost              CatBoost Classifier    0.6777  0.7614  0.6987  0.6746
# et                 Extra Trees Classifier    0.6694  0.7510  0.6519  0.6795
# rf               Random Forest Classifier    0.6841  0.7491  0.6924  0.6857
# lightgbm  Light Gradient Boosting Machine    0.6605  0.7396  0.6696  0.6630
# ada                  Ada Boost Classifier    0.6650  0.7431  0.6772  0.6660
# knn                K Neighbors Classifier    0.6349  0.6841  0.6646  0.6325
# xgboost         Extreme Gradient Boosting    0.6675  0.7361  0.6722  0.6707
# qda       Quadratic Discriminant Analysis    0.6337  0.6971  0.6823  0.6392
# dummy                    Dummy Classifier    0.5042  0.5000  1.0000  0.5042
# nb                            Naive Bayes    0.6802  0.7490  0.6658  0.6901
# dt               Decision Tree Classifier    0.6037  0.6036  0.6127  0.6064
#
#               F1   Kappa     MCC  LogLoss   Brier  TT (Sec)
# lr        0.6969  0.3872  0.3880   0.5614  0.1915     0.012
# lda       0.6986  0.3911  0.3918   0.5619  0.1917     0.009
# gbc       0.6895  0.3615  0.3625   0.5845  0.2004     0.239
# catboost  0.6857  0.3551  0.3563   0.5871  0.2012     2.943
# et        0.6648  0.3389  0.3397   0.5884  0.2026     0.167
# rf        0.6881  0.3680  0.3690   0.6112  0.2031     0.218
# lightgbm  0.6648  0.3208  0.3224   0.6797  0.2244     0.237
# ada       0.6703  0.3297  0.3310   0.6671  0.2376     0.089
# knn       0.6473  0.2694  0.2707   1.8020  0.2384     0.019
# xgboost   0.6703  0.3349  0.3361   0.7655  0.2391     0.241
# qda       0.6464  0.2661  0.2808   0.7827  0.2495     0.009
# dummy     0.6703  0.0000  0.0000   0.6931  0.2500     0.008
# nb        0.6770  0.3606  0.3616   1.1984  0.2634     0.009
# dt        0.6085  0.2073  0.2080  13.6880  0.3963     0.015
# INFO:logs:create_model_container: 14
# INFO:logs:master_model_container: 14
# INFO:logs:display_container: 2
# INFO:logs:[LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=4629, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001), GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=4629, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)]
# INFO:logs:compare_models() succesfully completed......................................

# %%
# 가장 좋은 모델에 대해 튜닝

tuned_top = [tune_model(i, optimize = 'Brier') for i in custom_model]
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC  LogLoss  \
# Fold
# 0       0.7516  0.8306  0.7722  0.7439  0.7578  0.5030  0.5034   0.5294
# 1       0.6752  0.7559  0.7089  0.6667  0.6871  0.3500  0.3507   0.5937
# 2       0.6752  0.7476  0.6962  0.6707  0.6832  0.3501  0.3504   0.6003
# 3       0.6624  0.7261  0.6962  0.6548  0.6748  0.3245  0.3252   0.6060
# 4       0.6624  0.7467  0.6962  0.6548  0.6748  0.3245  0.3252   0.5915
# 5       0.7325  0.7988  0.7089  0.7467  0.7273  0.4651  0.4657   0.5526
# 6       0.7389  0.8275  0.7595  0.7317  0.7453  0.4776  0.4779   0.5272
# 7       0.6987  0.8016  0.7975  0.6702  0.7283  0.3958  0.4034   0.5499
# 8       0.6731  0.7332  0.6709  0.6795  0.6752  0.3462  0.3462   0.6034
# 9       0.6795  0.7365  0.7468  0.6629  0.7024  0.3578  0.3608   0.6024
# Mean    0.6949  0.7704  0.7253  0.6882  0.7056  0.3895  0.3909   0.5756
# Std     0.0319  0.0380  0.0388  0.0353  0.0299  0.0639  0.0639   0.0304
#
#        Brier
# Fold
# 0     0.1752
# 1     0.2027
# 2     0.2061
# 3     0.2106
# 4     0.2036
# 5     0.1860
# 6     0.1741
# 7     0.1856
# 8     0.2079
# 9     0.2083
# Mean  0.1960
# Std   0.0135
# INFO:logs:create_model_container: 17
# INFO:logs:master_model_container: 17
# INFO:logs:display_container: 5
# INFO:logs:GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.01, loss='deviance', max_depth=4,
#                            max_features=1.0, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0005,
#                            min_impurity_split=None, min_samples_leaf=1,
#                            min_samples_split=9, min_weight_fraction_leaf=0.0,
#                            n_estimators=200, n_iter_no_change=None,
#                            presort='deprecated', random_state=4629,
#                            subsample=0.8, tol=0.0001, validation_fraction=0.1,
#                            verbose=0, warm_start=False)
# INFO:logs:tune_model() succesfully completed......................................

# %%
# Brier score

blended_custom = blend_models(estimator_list = tuned_top,
                              fold = 10,
                              optimize = 'Brier')

pred_holdout_custom = predict_model(blended_custom)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC  LogLoss  \
# Fold
# 0       0.7261  0.8429  0.7342  0.7250  0.7296  0.4522  0.4522   0.5002
# 1       0.7006  0.7618  0.7342  0.6905  0.7117  0.4010  0.4018   0.5833
# 2       0.7070  0.7507  0.7342  0.6988  0.7160  0.4138  0.4143   0.5943
# 3       0.6752  0.7395  0.6962  0.6707  0.6832  0.3501  0.3504   0.5987
# 4       0.6943  0.7691  0.7468  0.6782  0.7108  0.3881  0.3901   0.5729
# 5       0.7006  0.7958  0.6456  0.7286  0.6846  0.4017  0.4043   0.5503
# 6       0.7452  0.8390  0.7468  0.7468  0.7468  0.4904  0.4904   0.5123
# 7       0.7308  0.8121  0.7595  0.7229  0.7407  0.4611  0.4617   0.5306
# 8       0.6667  0.7398  0.6329  0.6849  0.6579  0.3339  0.3349   0.5958
# 9       0.6859  0.7519  0.7722  0.6630  0.7135  0.3703  0.3756   0.5847
# Mean    0.7032  0.7803  0.7203  0.7009  0.7095  0.4063  0.4076   0.5623
# Std     0.0236  0.0375  0.0447  0.0268  0.0261  0.0472  0.0466   0.0347
#
#        Brier
# Fold
# 0     0.1652
# 1     0.1979
# 2     0.2034
# 3     0.2075
# 4     0.1957
# 5     0.1873
# 6     0.1684
# 7     0.1793
# 8     0.2068
# 9     0.2025
# Mean  0.1914
# Std   0.0149
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 6
# INFO:logs:VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                          min_impurity_decrease=0.0005,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=9,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=200,
#                                                          n_iter_no_change=None,
#                                                          presort='deprecated',
#                                                          random_state=4629,
#                                                          subsample=0.8,
#                                                          tol=0.0001,
#                                                          validation_fraction=0.1,
#                                                          verbose=0,
#                                                          warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)
# INFO:logs:blend_models() succesfully completed......................................
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                          min_impurity_decrease=0.0005,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=9,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=200,
#                                                          n_iter_no_change=None,
#                                                          presort='deprecated',
#                                                          random_state=4629,
#                                                          subsample=0.8,
#                                                          tol=0.0001,
#                                                          validation_fraction=0.1,
#                                                          verbose=0,
#                                                          warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None), probability_threshold=None, encoded_labels=False, drift_report=False, raw_score=False, round=4, verbose=True, ml_usecase=MLUsecase.CLASSIFICATION, display=None, drift_kwargs=None)
# INFO:logs:Checking exceptions
# INFO:logs:Preloading libraries
# INFO:logs:Preparing display monitor
#                Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# 0  Voting Classifier    0.6954  0.7861  0.6727  0.6959  0.6841  0.3902
#
#       MCC  LogLoss   Brier
# 0  0.3904   0.5536  0.1882

# %%
#최종 모델
final_model_custom = finalize_model(blended_custom)
# Out:
# INFO:logs:Initializing finalize_model()
# INFO:logs:finalize_model(estimator=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                          min_impurity_decrease=0.0005,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=9,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=200,
#                                                          n_iter_no_change=None,
#                                                          presort='deprecated',
#                                                          random_state=4629,
#                                                          subsample=0.8,
#                                                          tol=0.0001,
#                                                          validation_fraction=0.1,
#                                                          verbose=0,
#                                                          warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None), fit_kwargs=None, groups=None, model_only=True, display=None, experiment_custom_tags=None, return_train_score=False)
# INFO:logs:Finalizing VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                          min_impurity_decrease=0.0005,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=9,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=200,
#                                                          n_iter_no_change=None,
#                                                          presort='deprecated',
#                                                          random_state=4629,
#                                                          subsample=0.8,
#                                                          tol=0.0001,
#                                                          validation_fraction=0.1,
#                                                          verbose=0,
#                                                          warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)
# INFO:logs:Initializing create_model()
# INFO:logs:create_model(estimator=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                          min_impurity_decrease=0.0005,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=9,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=200,
#                                                          n_iter_no_change=None,
#                                                          presort='deprecated',
#                                                          random_state=4629,
#                                                          subsample=0.8,
#                                                          tol=0.0001,
#                                                          validation_fraction=0.1,
#                                                          verbose=0,
#                                                          warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None), fold=None, round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=True, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=False, probability_threshold=None, display=None, return_train_score=False, kwargs={})
# INFO:logs:Checking exceptions
# INFO:logs:Importing libraries
# INFO:logs:Copying training dataset
# INFO:logs:Defining folds
# INFO:logs:Declaring metric variables
# INFO:logs:Importing untrained model
# INFO:logs:Declaring custom model
# INFO:logs:Voting Classifier Imported succesfully
# INFO:logs:Starting cross validation
# INFO:logs:Cross validating with StratifiedKFold(n_splits=10, random_state=None, shuffle=False), n_jobs=-1
# INFO:logs:Calculating mean and std
# INFO:logs:Creating metrics dataframe
# INFO:logs:Finalizing model
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 8
# INFO:logs:VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                          min_impurity_decrease=0.0005,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=9,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=200,
#                                                          n_iter_no_change=None,
#                                                          presort='deprecated',
#                                                          random_state=4629,
#                                                          subsample=0.8,
#                                                          tol=0.0001,
#                                                          validation_fraction=0.1,
#                                                          verbose=0,
#                                                          warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)
# INFO:logs:create_model() succesfully completed......................................
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 7
# INFO:logs:VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                          min_impurity_decrease=0.0005,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=9,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=200,
#                                                          n_iter_no_change=None,
#                                                          presort='deprecated',
#                                                          random_state=4629,
#                                                          subsample=0.8,
#                                                          tol=0.0001,
#                                                          validation_fraction=0.1,
#                                                          verbose=0,
#                                                          warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)
# INFO:logs:finalize_model() succesfully completed......................................

# %%
#
import datetime

now = datetime.datetime.now()

save_model(final_model_custom, f"/content/Model_MAN_test_{datetime.datetime.now()}")

prep_pipe = get_config("prep_pipe")

prep_pipe.steps.append(['trained_model', final_model_custom])

man_predictions = predict_model(prep_pipe,
                                data=test_df_man,
                                raw_score=True)
# Out:
# INFO:logs:Initializing save_model()
# INFO:logs:save_model(model=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                      max_depth=4,
#                                                      max_features=1.0,
#                                                      max_leaf_nodes=None,
#                                                      max_samples=None,
#                                                      min_impurity_decrease=0.001,
#                                                      min_impurity_split=None,
#                                                      min_samples_leaf=6,
#                                                      min_samples_split=10,
#                                                      min_weight_fraction_leaf=0.0,
#                                                      n_estimators=200,
#                                                      n_jobs=-1, oob_score=False,
#                                                      random_state=4629,
#                                                      verbose=0,
#                                                      warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None), model_name=/content/Model_MAN_test_2023-03-05 14:01:45.902745, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                   target='WinA')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='WinA')),
#                 ('fix_perfect', Remove_100(target='WinA')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False), verbose=True, kwargs={})
# INFO:logs:Adding model into prep_pipe
# INFO:logs:/content/Model_MAN_test_2023-03-05 14:01:45.902745.pkl saved in current working directory
# INFO:logs:Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                                       max_features=1.0,
#                                                                       max_leaf_nodes=None,
#                                                                       max_samples=None,
#                                                                       min_impurity_decrease=0.001,
#                                                                       min_impurity_split=None,
#                                                                       min_samples_leaf=6,
#                                                                       min_samples_split=10,
#                                                                       min_weight_fraction_leaf=0.0,
#                                                                       n_estimators=200,
#                                                                       n_jobs=-1,
#                                                                       oob_score=False,
#                                                                       random_state=4629,
#                                                                       verbose=0,
#                                                                       warm_start=False))],
#                                   flatten_transform=True, n_jobs=-1,
#                                   verbose=False, voting='soft',
#                                   weights=None)]],
#          verbose=False)
# INFO:logs:save_model() successfully completed......................................
# Transformation Pipeline and Model Successfully Saved
# INFO:logs:Initializing get_config()
# INFO:logs:get_config(variable=prep_pipe)
# INFO:logs:Global variable: prep_pipe returned as Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                   target='WinA')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='WinA')),
#                 ('fix_perfect', Remove_100(target='WinA')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# INFO:logs:get_config() succesfully completed......................................
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                                       max_features=1.0,
#                                                                       max_leaf_nodes=None,
#                                                                       max_samples=None,
#                                                                       min_impurity_decrease=0.001,
#                                                                       min_impurity_split=None,
#                                                                       min_samples_leaf=6,
#                                                                       min_samples_split=10,
#                                                                       min_weight_fraction_leaf=0.0,
#                                                                       n_estimators=200,
#                                                                       n_jobs=-1,
#                                                                       oob_score=False,
#                                                                       random_state=4629,
#                                                                       verbose=0,
#                                                                       warm_start=False))],
#                                   flatten_transform=True, n_jobs=-1,
#                                   verbose=False, voting='soft',
#                                   weights=None)]],
#          verbose=False), probability_threshold=None, encoded_labels=False, drift_report=False, raw_score=True, round=4, verbose=True, ml_usecase=MLUsecase.CLASSIFICATION, display=None, drift_kwargs=None)
# INFO:logs:Checking exceptions
# INFO:logs:Preloading libraries
# INFO:logs:Preparing display monitor

# %%
test_df_man_after_AutoML = test_df_man.copy()

test_df_man_after_AutoML['pred'] = man_predictions['Score_1']

_ = sns.displot(man_predictions['Score_1'])

# %%
def visualize_result(df,prep_pipe, types = None):

  if types == 'man':
    df = df[df['Season'] >= 2003][df[df['Season'] >= 2003]['TeamIdA'].astype('str').str.contains('^1',regex= True)]

  elif types == 'woman':
    df = df[df['Season'] >= 2013][df[df['Season'] >= 2013]['TeamIdA'].astype('str').str.contains('^3',regex= True)]

  else:
    pass

  for year in df['Season'].unique():      
      
    df_val = df[df['Season'] == year]

    df_val = df_val.reset_index(drop=True)

    prediction = prep_pipe.predict_proba(df_val[features])

    i, j = [], []
    for row in prediction:
      i.append(row[0])
      j.append(row[1])

    len(i), len(j)

    df_val['pred'] = j

    df_val['WinA_pred'] = prep_pipe.predict(df_val[features])
    
    #plt.figure(figsize=(12, 6))
    fig, ax = plt.subplots(1, 2,figsize = [12, 6])
    ax[0].set_ylim(-60, 60)
    ax[0].scatter(df_val['pred'], df_val['ScoreDiff'].values, s=10)
    ax[0].set_title('Prediction vs Score Diff')

    ax[1].hist(df_val['pred'], bins = 10, alpha = 0.4)
    ax[1].set_title('Predictions probability repartition')

    fig.suptitle(f'{year} Result', fontsize=16) # figure 제목

    fig.tight_layout() # 사용하면 플롯간 여백을 조정해준다. 
    plt.show()
    
    print(f'{year} Score : ', brier_score_loss(df_val['WinA'], df_val['pred']))

# %% [markdown]
# ## woman

# %%
#https://pycaret.readthedocs.io/en/latest/api/regression.html

from pycaret.classification import *

clf_test_3 = setup(data=train_df_woman,   # df 설정
                   target='WinA', # Target 설정
                   train_size= 0.7, # size 설정
                   fold=10,
                   normalize = True,
                   transformation = False,
                   pca = False,
                   feature_selection = False,
                   session_id = 4629,
                   silent=True,
                   #remove_outliers = True,
                   #use_gpu = True,
                   #ordinal_features = {'key' : [i for i in range(12)]}'# Fold 설정
                   )

#logloss 적용 및 predict_proba로 제출하기 위해 metric 추가
add_metric('logloss', 'LogLoss', log_loss, greater_is_better=False, target="pred_proba")

from sklearn.metrics import brier_score_loss

add_metric('Brier', 'Brier', brier_score_loss, greater_is_better=False, target="pred_proba")
# Out:
#                                Description             Value
# 0                               session_id              4629
# 1                                   Target              WinA
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data        (1142, 17)
# 5                           Missing Values             False
# 6                         Numeric Features                15
# 7                     Categorical Features                 1
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (799, 30)
# 12                    Transformed Test Set         (343, 30)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              6e4f
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize              True
# 30                        Normalize Method            zscore
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE
# INFO:logs:create_model_container: 0
# INFO:logs:master_model_container: 0
# INFO:logs:display_container: 1
# INFO:logs:Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                   target='WinA')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='WinA')),
#                 ('fix_perfect', Remove_100(target='WinA')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# INFO:logs:setup() succesfully completed......................................
# Name                                                             Brier
# Display Name                                                     Brier
# Score Function           <function brier_score_loss at 0x7fdd639520d0>
# Scorer               make_scorer(brier_score_loss, greater_is_bette...
# Target                                                      pred_proba
# Args                                                                {}
# Greater is Better                                                False
# Multiclass                                                        True
# Custom                                                            True
# Name: Brier, dtype: object

# %%
#Brier score가 높은 모델 3개를 앙상블 (제외된 2개의 모델은 Brier score를 구할 수 없어서 제외함)

custom_model = compare_models(fold = 10, 
                              sort = 'Brier', 
                              n_select = 3, 
                              exclude=['svm','ridge','catboost'])
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7485  0.8436  0.7496  0.7510
# lda          Linear Discriminant Analysis    0.7435  0.8391  0.7345  0.7503
# et                 Extra Trees Classifier    0.7510  0.8300  0.7621  0.7471
# rf               Random Forest Classifier    0.7397  0.8235  0.7346  0.7444
# gbc          Gradient Boosting Classifier    0.7221  0.8212  0.7344  0.7185
# knn                K Neighbors Classifier    0.7246  0.7949  0.7369  0.7231
# lightgbm  Light Gradient Boosting Machine    0.7334  0.8189  0.7344  0.7316
# ada                  Ada Boost Classifier    0.7146  0.8085  0.6893  0.7265
# xgboost         Extreme Gradient Boosting    0.7285  0.8122  0.7395  0.7229
# dummy                    Dummy Classifier    0.5006  0.5000  0.0000  0.0000
# dt               Decision Tree Classifier    0.6758  0.6758  0.6765  0.6760
# nb                            Naive Bayes    0.6346  0.8120  0.9749  0.5807
# qda       Quadratic Discriminant Analysis    0.5931  0.5963  0.7325  0.5149
#
#               F1   Kappa     MCC  LogLoss   Brier  TT (Sec)
# lr        0.7478  0.4970  0.5002   0.4775  0.1624     0.039
# lda       0.7403  0.4870  0.4895   0.4898  0.1662     0.014
# et        0.7526  0.5020  0.5047   0.4905  0.1669     0.159
# rf        0.7370  0.4795  0.4824   0.5116  0.1711     0.207
# gbc       0.7239  0.4444  0.4475   0.5188  0.1788     0.199
# knn       0.7276  0.4493  0.4522   1.4508  0.1888     0.041
# lightgbm  0.7313  0.4669  0.4693   0.6476  0.1984     0.163
# ada       0.7056  0.4293  0.4317   0.5955  0.2046     0.096
# xgboost   0.7302  0.4570  0.4582   0.7166  0.2079     0.307
# dummy     0.0000  0.0000  0.0000   0.6931  0.2500     0.019
# dt        0.6742  0.3516  0.3540  11.1968  0.3242     0.017
# nb        0.7275  0.2697  0.3683   6.4391  0.3580     0.023
# qda       0.5909  0.1850  0.2431  13.7835  0.4071     0.015
# INFO:logs:create_model_container: 13
# INFO:logs:master_model_container: 13
# INFO:logs:display_container: 2
# INFO:logs:[LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=4629, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001), ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=4629, verbose=0,
#                      warm_start=False)]
# INFO:logs:compare_models() succesfully completed......................................

# %%
# 가장 좋은 모델에 대해 튜닝

tuned_top = [tune_model(i, optimize = 'Brier') for i in custom_model]
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC  LogLoss  \
# Fold
# 0       0.7750  0.8606  0.7750  0.7750  0.7750  0.5500  0.5500   0.4573
# 1       0.7750  0.8606  0.7500  0.7895  0.7692  0.5500  0.5507   0.4583
# 2       0.7750  0.8131  0.8000  0.7619  0.7805  0.5500  0.5507   0.5063
# 3       0.7750  0.8838  0.7500  0.7895  0.7692  0.5500  0.5507   0.4438
# 4       0.6750  0.7812  0.6250  0.6944  0.6579  0.3500  0.3518   0.5342
# 5       0.7500  0.8344  0.7000  0.7778  0.7368  0.5000  0.5025   0.4854
# 6       0.8000  0.8962  0.8250  0.7857  0.8049  0.6000  0.6008   0.4219
# 7       0.7500  0.8444  0.8000  0.7273  0.7619  0.5000  0.5025   0.4841
# 8       0.7375  0.8450  0.6000  0.8276  0.6957  0.4750  0.4940   0.4933
# 9       0.7848  0.8897  0.7692  0.7895  0.7792  0.5694  0.5696   0.4272
# Mean    0.7597  0.8509  0.7394  0.7718  0.7530  0.5194  0.5223   0.4712
# Std     0.0332  0.0339  0.0715  0.0351  0.0422  0.0665  0.0650   0.0340
#
#        Brier
# Fold
# 0     0.1528
# 1     0.1513
# 2     0.1731
# 3     0.1459
# 4     0.1865
# 5     0.1634
# 6     0.1371
# 7     0.1616
# 8     0.1642
# 9     0.1396
# Mean  0.1576
# Std   0.0145
# INFO:logs:create_model_container: 16
# INFO:logs:master_model_container: 16
# INFO:logs:display_container: 5
# INFO:logs:ExtraTreesClassifier(bootstrap=True, ccp_alpha=0.0, class_weight={},
#                      criterion='gini', max_depth=4, max_features=1.0,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.001, min_impurity_split=None,
#                      min_samples_leaf=6, min_samples_split=10,
#                      min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#                      oob_score=False, random_state=4629, verbose=0,
#                      warm_start=False)
# INFO:logs:tune_model() succesfully completed......................................

# %%
# Brier score

blended_custom = blend_models(estimator_list = tuned_top,
                              fold = 10,
                              optimize = 'Brier')

pred_holdout_custom = predict_model(blended_custom)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC  LogLoss  \
# Fold
# 0       0.7625  0.8619  0.7500  0.7692  0.7595  0.5250  0.5252   0.4572
# 1       0.7750  0.8575  0.7500  0.7895  0.7692  0.5500  0.5507   0.4665
# 2       0.6875  0.8000  0.7750  0.6596  0.7126  0.3750  0.3809   0.5203
# 3       0.7625  0.8619  0.7000  0.8000  0.7467  0.5250  0.5292   0.4491
# 4       0.7000  0.7925  0.6500  0.7222  0.6842  0.4000  0.4020   0.5405
# 5       0.7375  0.8325  0.7000  0.7568  0.7273  0.4750  0.4763   0.4874
# 6       0.8000  0.9038  0.8500  0.7727  0.8095  0.6000  0.6030   0.4026
# 7       0.7250  0.8487  0.8000  0.6957  0.7442  0.4500  0.4551   0.4814
# 8       0.7500  0.8525  0.6250  0.8333  0.7143  0.5000  0.5164   0.4849
# 9       0.7848  0.8910  0.8205  0.7619  0.7901  0.5700  0.5716   0.4105
# Mean    0.7485  0.8502  0.7421  0.7561  0.7458  0.4970  0.5010   0.4700
# Std     0.0344  0.0332  0.0693  0.0486  0.0360  0.0688  0.0681   0.0411
#
#        Brier
# Fold
# 0     0.1547
# 1     0.1554
# 2     0.1813
# 3     0.1502
# 4     0.1906
# 5     0.1650
# 6     0.1298
# 7     0.1620
# 8     0.1599
# 9     0.1351
# Mean  0.1584
# Std   0.0175
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 8
# INFO:logs:VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)
# INFO:logs:blend_models() succesfully completed......................................
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None), probability_threshold=None, encoded_labels=False, drift_report=False, raw_score=False, round=4, verbose=True, ml_usecase=MLUsecase.CLASSIFICATION, display=None, drift_kwargs=None)
# INFO:logs:Checking exceptions
# INFO:logs:Preloading libraries
# INFO:logs:Preparing display monitor
#                Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# 0  Voting Classifier    0.8222  0.9042  0.7907  0.8447  0.8168  0.6444
#
#       MCC  LogLoss   Brier
# 0  0.6457   0.3991  0.1284

# %%
#최종 모델
final_model_custom = finalize_model(blended_custom)
# Out:
# INFO:logs:Initializing finalize_model()
# INFO:logs:finalize_model(estimator=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None), fit_kwargs=None, groups=None, model_only=True, display=None, experiment_custom_tags=None, return_train_score=False)
# INFO:logs:Finalizing VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)
# INFO:logs:Initializing create_model()
# INFO:logs:create_model(estimator=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None), fold=None, round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=True, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=False, probability_threshold=None, display=None, return_train_score=False, kwargs={})
# INFO:logs:Checking exceptions
# INFO:logs:Importing libraries
# INFO:logs:Copying training dataset
# INFO:logs:Defining folds
# INFO:logs:Declaring metric variables
# INFO:logs:Importing untrained model
# INFO:logs:Declaring custom model
# INFO:logs:Voting Classifier Imported succesfully
# INFO:logs:Starting cross validation
# INFO:logs:Cross validating with StratifiedKFold(n_splits=10, random_state=None, shuffle=False), n_jobs=-1
# INFO:logs:Calculating mean and std
# INFO:logs:Creating metrics dataframe
# INFO:logs:Finalizing model
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 10
# INFO:logs:VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)
# INFO:logs:create_model() succesfully completed......................................
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 9
# INFO:logs:VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)
# INFO:logs:finalize_model() succesfully completed......................................

# %%
#
import datetime

now = datetime.datetime.now()

save_model(final_model_custom, f"/content/Model_WOMAN_test_{datetime.datetime.now()}")

prep_pipe = get_config("prep_pipe")

prep_pipe.steps.append(['trained_model', final_model_custom])

woman_predictions = predict_model(prep_pipe,
                                data=test_df_woman,
                                raw_score=True)
# Out:
# INFO:logs:Initializing save_model()
# INFO:logs:save_model(model=VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=0.356, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=4629,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('lda',
#                               LinearDiscriminantAnalysis(n_components=None,
#                                                          priors=None,
#                                                          shrinkage=0.0...
#                                                    max_depth=4,
#                                                    max_features=1.0,
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.001,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=6,
#                                                    min_samples_split=10,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=200, n_jobs=-1,
#                                                    oob_score=False,
#                                                    random_state=4629, verbose=0,
#                                                    warm_start=False))],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None), model_name=/content/Model_WOMAN_test_2023-03-05 14:22:44.809007, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                   target='WinA')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='WinA')),
#                 ('fix_perfect', Remove_100(target='WinA')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False), verbose=True, kwargs={})
# INFO:logs:Adding model into prep_pipe
# INFO:logs:/content/Model_WOMAN_test_2023-03-05 14:22:44.809007.pkl saved in current working directory
# INFO:logs:Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                                     max_features=1.0,
#                                                                     max_leaf_nodes=None,
#                                                                     max_samples=None,
#                                                                     min_impurity_decrease=0.001,
#                                                                     min_impurity_split=None,
#                                                                     min_samples_leaf=6,
#                                                                     min_samples_split=10,
#                                                                     min_weight_fraction_leaf=0.0,
#                                                                     n_estimators=200,
#                                                                     n_jobs=-1,
#                                                                     oob_score=False,
#                                                                     random_state=4629,
#                                                                     verbose=0,
#                                                                     warm_start=False))],
#                                   flatten_transform=True, n_jobs=-1,
#                                   verbose=False, voting='soft',
#                                   weights=None)]],
#          verbose=False)
# INFO:logs:save_model() successfully completed......................................
# Transformation Pipeline and Model Successfully Saved
# INFO:logs:Initializing get_config()
# INFO:logs:get_config(variable=prep_pipe)
# INFO:logs:Global variable: prep_pipe returned as Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                   target='WinA')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='WinA')),
#                 ('fix_perfect', Remove_100(target='WinA')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# INFO:logs:get_config() succesfully completed......................................
# INFO:logs:Initializing predict_model()
# INFO:logs:predict_model(estimator=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='WinA',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strate...
#                                                                     max_features=1.0,
#                                                                     max_leaf_nodes=None,
#                                                                     max_samples=None,
#                                                                     min_impurity_decrease=0.001,
#                                                                     min_impurity_split=None,
#                                                                     min_samples_leaf=6,
#                                                                     min_samples_split=10,
#                                                                     min_weight_fraction_leaf=0.0,
#                                                                     n_estimators=200,
#                                                                     n_jobs=-1,
#                                                                     oob_score=False,
#                                                                     random_state=4629,
#                                                                     verbose=0,
#                                                                     warm_start=False))],
#                                   flatten_transform=True, n_jobs=-1,
#                                   verbose=False, voting='soft',
#                                   weights=None)]],
#          verbose=False), probability_threshold=None, encoded_labels=False, drift_report=False, raw_score=True, round=4, verbose=True, ml_usecase=MLUsecase.CLASSIFICATION, display=None, drift_kwargs=None)
# INFO:logs:Checking exceptions
# INFO:logs:Preloading libraries
# INFO:logs:Preparing display monitor

# %%
train_df_woman['WinA'].value_counts()
# Out:
# 1    571
# 0    571
# Name: WinA, dtype: int64

# %%
test_df_woman_after_AutoML = test_df_woman.copy()

test_df_woman_after_AutoML['pred'] = woman_predictions['Score_1']

_ = sns.displot(woman_predictions['Score_1'])

# %%
test_df_woman_after_AutoML[test_df_woman_after_AutoML['pred'] <= 0.5]
# Out:
#         SeedA  SeedDiff  WinRatioA  WinRatioDiff    GapAvgA  GapAvgDiff  \
# 65965       1         0   0.391304     -0.608696   2.000000  -30.444444
# 66081       1         0   0.400000     -0.215385  -2.000000  -12.769231
# 66229       1         0   0.400000     -0.100000  -2.000000  -14.307692
# 66281       1         0   0.400000     -0.118519  -2.000000  -12.074074
# 66324       1         0   0.400000     -0.600000  -2.000000  -34.444444
# ...       ...       ...        ...           ...        ...         ...
# 130467      1         0   0.560000      0.136923  -1.680000   -1.718462
# 130632      1         0   0.440000      0.016923  -7.480000   -7.518462
# 130635      1         0   0.440000      0.106667  -7.480000   -4.355000
# 130652      1         0   0.608696      0.275362   3.304348    6.429348
# 130677      1         0   0.217391     -0.115942 -13.347826  -10.222826
#
#           FGDiff   FG3Diff    FTDiff  TOmarginDiff  WinRatio_3yearsDiff  \
# 65965  -0.029333  0.020656 -0.000409      1.621578            -0.472689
# 66081  -0.032855  0.000727  0.064032     -4.221538            -0.367621
# 66229  -0.027309  0.005613  0.087446     -0.683077            -0.121227
# 66281  -0.030228 -0.025475  0.051381     -4.908148            -0.166667
# 66324  -0.071874  0.008463  0.064330     -4.834074            -0.505495
# ...          ...       ...       ...           ...                  ...
# 130467 -0.028061  0.004767  0.087115     -4.189231             0.009759
# 130632 -0.031953 -0.013580 -0.016747     -0.229231            -0.044289
# 130635 -0.006985  0.023391 -0.091581     -1.460000             0.045455
# 130652  0.070353  0.084992 -0.050269     -0.065217             0.066667
# 130677 -0.040621 -0.004718 -0.128642     -4.108696            -0.115942
#
#         GapAvg_3yearsDiff  AdjODiff  AdjDDiff  AdjEMDiff  LuckyDiff    pred
# 65965          -22.669945 -0.087290  0.219264  -0.306554  -0.152110  0.4667
# 66081          -19.861010 -0.069692  0.054764  -0.124457  -0.027502  0.4994
# 66229           -8.969640 -0.102218  0.028919  -0.131138   0.053446  0.4618
# 66281          -12.216058 -0.103899  0.019459  -0.123358   0.023849  0.4844
# 66324          -24.586974 -0.183806  0.163713  -0.347520  -0.092647  0.4131
# ...                   ...       ...       ...        ...        ...     ...
# 130467          -4.577825 -0.003094  0.016759  -0.019852   0.113524  0.4927
# 130632          -5.574648 -0.046933  0.026854  -0.073787   0.072889  0.4802
# 130635          -2.411187  0.014674  0.057669  -0.042994   0.104492  0.4857
# 130652          -5.164390  0.125035  0.066836   0.058199   0.129086  0.4966
# 130677         -10.222826 -0.046801  0.051788  -0.098590   0.084485  0.4784
#
# [4674 rows x 17 columns]

# %% [markdown]
# ## 통합

# %%
test_df_2_after_AutoML = pd.concat([test_df_man_after_AutoML, test_df_woman_after_AutoML])

test_df_2_after_AutoML = pd.concat([test_df_2_after_AutoML, df_test['ID']],axis=1)

final_sub2 = test_df_2_after_AutoML[['ID','pred']]

# %%
final_sub2.to_csv('submission_cross_2.csv', index=False)

# %%
_ = sns.displot(test_df_2_after_AutoML['pred'])

# %%
test_df_2_after_AutoML[test_df_2_after_AutoML['pred'] < 0.5]
# Out:
#         SeedA  SeedDiff  WinRatioA  WinRatioDiff    GapAvgA  GapAvgDiff  \
# 13          1         0   0.409091     -0.269481  -2.863636  -12.327922
# 55          1         0   0.409091     -0.331650  -2.863636  -16.567340
# 113         1         0   0.409091     -0.516835  -2.863636  -22.752525
# 142         1         0   0.409091     -0.321678  -2.863636  -13.825175
# 284         1         0   0.409091     -0.305195  -2.863636  -17.077922
# ...       ...       ...        ...           ...        ...         ...
# 130662      1         0   0.461538      0.038462  -3.961538   -4.000000
# 130665      1         0   0.461538      0.128205  -3.961538   -0.836538
# 130674      1         0   0.043478     -0.289855 -18.086957  -14.961957
# 130677      1         0   0.217391     -0.115942 -13.347826  -10.222826
# 130678      1         0   0.217391     -0.051839 -13.347826   -6.424749
#
#           FGDiff   FG3Diff    FTDiff  TOmarginDiff  WinRatio_3yearsDiff  \
# 13     -0.037518  0.038953  0.014063     -2.814935            -0.106438
# 55     -0.002532  0.007601 -0.031987     -3.136364            -0.080914
# 113    -0.022909  0.015627 -0.031561      0.271044            -0.249922
# 142    -0.019266 -0.008904 -0.010385     -2.328671            -0.077365
# 284     0.019287  0.037946 -0.033994     -1.100649            -0.100497
# ...          ...       ...       ...           ...                  ...
# 130662 -0.030196 -0.006362  0.067473      1.192308             0.024684
# 130665 -0.005229  0.030610 -0.007361     -0.038462             0.114428
# 130674 -0.000141  0.016693 -0.087440      2.978261            -0.289855
# 130677 -0.040621 -0.004718 -0.128642     -4.108696            -0.115942
# 130678 -0.031983 -0.033984 -0.067519     -4.877926            -0.051839
#
#         GapAvg_3yearsDiff  AdjODiff  AdjDDiff  AdjEMDiff  LuckyDiff    pred  \
# 13              -4.323071 -0.021773  0.096191  -0.117965  -0.021278  0.4797
# 55              -5.067966 -0.077446  0.082120  -0.159566  -0.015413  0.4875
# 113            -12.750034 -0.116538  0.127425  -0.243964  -0.094804  0.3791
# 142             -3.557646 -0.054045  0.090237  -0.144283  -0.010897  0.4929
# 284             -5.972007 -0.026809  0.144355  -0.171165  -0.026976  0.4464
# ...                   ...       ...       ...        ...        ...     ...
# 130662          -3.614786 -0.060186 -0.019649  -0.040537   0.088154  0.4811
# 130665          -0.451325  0.001421  0.011165  -0.009744   0.119757  0.4781
# 130674         -14.961957 -0.025943  0.138567  -0.164510   0.018278  0.4919
# 130677         -10.222826 -0.046801  0.051788  -0.098590   0.084485  0.4147
# 130678          -6.424749 -0.053322  0.000654  -0.053977   0.067774  0.4892
#
#                     ID
# 13      2023_1101_1116
# 55      2023_1101_1163
# 113     2023_1101_1222
# 142     2023_1101_1251
# 284     2023_1101_1397
# ...                ...
# 130662  2023_3471_3472
# 130665  2023_3471_3475
# 130674  2023_3473_3475
# 130677  2023_3474_3475
# 130678  2023_3474_3476
#
# [25849 rows x 18 columns]

# %% [markdown]
# # Baseline & CV
